# %% [markdown]
# # N-grams and Markov chains
#
# By [Allison Parrish](http://www.decontextualize.com/)
# and re-used, edited by Defne Onen for CATN Fall 2019 Final Project.
#
# Markov chain text generation is [one of the oldest](https://elmcip.net/creative-work/travesty) strategies for predictive text generation. This notebook takes you through the basics of implementing a simple and concise Markov chain text generation procedure in Python.

# %% [markdown]
# ## N-grams
#
# The first kind of text analysis that we’ll look at today is an n-gram model. An n-gram is simply a sequence of units drawn from a longer sequence; in the case of text, the unit in question is usually a character or a word. For convenience, we'll call the unit of the n-gram is called its *level*; the length of the n-gram is called its *order*.
#
# N-grams are used frequently in natural language processing and are a basic tool text analysis. Their applications range from programs that correct spelling to creative visualizations to compression algorithms to stylometrics to generative text. They can be used as the basis of a Markov chain algorithm—and, in fact, that’s one of the applications we’ll be using them for later in this lesson.
#
# ### Finding and counting word pairs
#
# So how would we go about writing Python code to find n-grams? We'll start with a simple task: finding *word pairs* in a text. A word pair is essentially a word-level order-2 n-gram; once we have code to find word pairs, we’ll generalize it to handle n-grams of any order.
#
# Open Runway - im2txt generated text below to create word pairs.

# %%
text = open("textInspiration.txt").read()
words = text.split()

# %%
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# %% [markdown]
# (Why `len(words) - 1`? Because the final element of the list can only be the *second* element of a pair. Otherwise we'd be trying to access an element beyond the end of the list.)
#
# The corresponding way to write this with a `for` loop:

# %%
pairs = []
for i in range(len(words)-1):
    this_pair = (words[i], words[i+1])
    pairs.append(this_pair)

# %% [markdown]
# In either case, the list of n-grams ends up looking like this. (I'm only showing the first 25 for the sake of brevity; remove `[:25]` to see the whole list.)

# %%
pairs[:25]
# Out:
# [('a', 'black'),
#  ('black', 'and'),
#  ('and', 'white'),
#  ('white', 'photo'),
#  ('photo', 'of'),
#  ('of', 'a'),
#  ('a', 'person'),
#  ('person', 'holding'),
#  ('holding', 'a'),
#  ('a', 'cell'),
#  ('cell', 'phone'),
#  ('phone', 'a'),
#  ('a', 'close'),
#  ('close', 'up'),
#  ('up', 'of'),
#  ('of', 'a'),
#  ('a', 'pair'),
#  ('pair', 'of'),
#  ('of', 'scissors'),
#  ('scissors', 'on'),
#  ('on', 'a'),
#  ('a', 'table'),
#  ('table', 'a'),
#  ('a', 'couple'),
#  ('couple', 'of')]

# %% [markdown]
# Now that we have a list of word pairs, we can count them using a `Counter` object.

# %%
from collections import Counter

# %%
pair_counts = Counter(pairs)

# %% [markdown]
# The `.most_common()` method of the `Counter` shows us the items in our list that occur most frequently:

# %%
pair_counts.most_common(10)
# Out:
# [(('of', 'a'), 514),
#  (('a', 'close'), 213),
#  (('close', 'up'), 213),
#  (('up', 'of'), 213),
#  (('on', 'a'), 174),
#  (('with', 'a'), 172),
#  (('a', 'clock'), 106),
#  (('table', 'a'), 105),
#  (('a', 'table'), 100),
#  (('sitting', 'on'), 100)]

# %% [markdown]
# So the phrase "af a" occurs 514 times, by far the most common word pair in the text. In fact, "of a" comprises about 5% of all word pairs found in the text:

# %%
pair_counts[("of", "a")] / sum(pair_counts.values())
# Out:
# 0.05937391706133765

# %% [markdown]
# You can do the same calculation with character-level pairs with pretty much exactly the same code, owing to the fact that strings and lists can be indexed using the same syntax:

# %%
char_pairs = [(text[i], text[i+1]) for i in range(len(text)-1)]

# %% [markdown]
# The variable `char_pairs` now has a list of all pairs of *characters* in the text. Using `Counter` again, we can find the most common pairs of characters:

# %%
char_pair_counts = Counter(char_pairs)
char_pair_counts.most_common(10)
# Out:
# [(('a', ' '), 2125),
#  ((' ', 'a'), 1489),
#  ((' ', 'o'), 1179),
#  (('n', ' '), 970),
#  (('e', ' '), 958),
#  (('\n', 'a'), 901),
#  (('i', 'n'), 876),
#  (('f', ' '), 787),
#  (('o', 'f'), 780),
#  ((' ', 's'), 749)]

# %% [markdown]
# ### N-grams of arbitrary lengths
#
# The step from pairs to n-grams of arbitrary lengths is a only a matter of using slice indexes to get a slice of length `n`, where `n` is the length of the desired n-gram. For example, to get all of the word-level order 7 n-grams from the list of words in `textInspiration.txt`:

# %%
seven_grams = [tuple(words[i:i+7]) for i in range(len(words)-6)]

# %%
seven_grams[:20]
# Out:
# [('a', 'black', 'and', 'white', 'photo', 'of', 'a'),
#  ('black', 'and', 'white', 'photo', 'of', 'a', 'person'),
#  ('and', 'white', 'photo', 'of', 'a', 'person', 'holding'),
#  ('white', 'photo', 'of', 'a', 'person', 'holding', 'a'),
#  ('photo', 'of', 'a', 'person', 'holding', 'a', 'cell'),
#  ('of', 'a', 'person', 'holding', 'a', 'cell', 'phone'),
#  ('a', 'person', 'holding', 'a', 'cell', 'phone', 'a'),
#  ('person', 'holding', 'a', 'cell', 'phone', 'a', 'close'),
#  ('holding', 'a', 'cell', 'phone', 'a', 'close', 'up'),
#  ('a', 'cell', 'phone', 'a', 'close', 'up', 'of'),
#  ('cell', 'phone', 'a', 'close', 'up', 'of', 'a'),
#  ('phone', 'a', 'close', 'up', 'of', 'a', 'pair'),
#  ('a', 'close', 'up', 'of', 'a', 'pair', 'of'),
#  ('close', 'up', 'of', 'a', 'pair', 'of', 'scissors'),
#  ('up', 'of', 'a', 'pair', 'of', 'scissors', 'on'),
#  ('of', 'a', 'pair', 'of', 'scissors', 'on', 'a'),
#  ('a', 'pair', 'of', 'scissors', 'on', 'a', 'table'),
#  ('pair', 'of', 'scissors', 'on', 'a', 'table', 'a'),
#  ('of', 'scissors', 'on', 'a', 'table', 'a', 'couple'),
#  ('scissors', 'on', 'a', 'table', 'a', 'couple', 'of')]

# %% [markdown]
# Two tricky things in this expression: in `tuple(words[i:i+7])`, I call `tuple()` to convert the list slice (`words[i:i+7]`) into a tuple. In `range(len(words)-6)`, the `6` is there because it's one fewer than the length of the n-gram. Just as with the pairs above, we need to stop counting before we reach the end of the list with enough room to make sure we're always grabbing slices of the desired length.
#
# For the sake of convenience, here's a function that will return n-grams of a desired length from any sequence, whether list or string:

# %%
def ngrams_for_sequence(n, seq):
    return [tuple(seq[i:i+n]) for i in range(len(seq)-n+1)]

# %% [markdown]
# Using this function, here are random character-level n-grams of order 9 from `textInspiration.txt`:

# %%
import random
genesis_9grams = ngrams_for_sequence(9, open("textInspiration.txt").read())
random.sample(genesis_9grams, 10)
# Out:
# [('n', ' ', 'f', 'r', 'o', 'n', 't', ' ', 'o'),
#  ('e', 'r', 'e', 'd', ' ', 'm', 'o', 'u', 'n'),
#  ('k', 'y', '\n', 'a', ' ', 'r', 'o', 'w', ' '),
#  ('s', 't', 'a', 'n', 'd', 'i', 'n', 'g', ' '),
#  ('r', 's', 'o', 'n', ' ', 'o', 'n', ' ', 'a'),
#  ('e', 'x', 't', ' ', 't', 'o', ' ', 'a', ' '),
#  (' ', 'a', ' ', 'p', 'a', 'i', 'r', ' ', 'o'),
#  (' ', 't', 'h', 'e', ' ', 'd', 'a', 'r', 'k'),
#  ('\n', 'a', ' ', 'r', 'e', 'd', ' ', 'u', 'm'),
#  ('o', 's', 'e', ' ', 'u', 'p', ' ', 'o', 'f')]

# %% [markdown]
# Or all the word-level 5-grams from `textInspiration.txt`:

# %%
textInspiration_word_5grams = ngrams_for_sequence(5, open("textInspiration.txt").read().split())
textInspiration_word_5grams
# Out:
# [('a', 'black', 'and', 'white', 'photo'),
#  ('black', 'and', 'white', 'photo', 'of'),
#  ('and', 'white', 'photo', 'of', 'a'),
#  ('white', 'photo', 'of', 'a', 'person'),
#  ('photo', 'of', 'a', 'person', 'holding'),
#  ('of', 'a', 'person', 'holding', 'a'),
#  ('a', 'person', 'holding', 'a', 'cell'),
#  ('person', 'holding', 'a', 'cell', 'phone'),
#  ('holding', 'a', 'cell', 'phone', 'a'),
#  ('a', 'cell', 'phone', 'a', 'close'),
#  ('cell', 'phone', 'a', 'close', 'up'),
#  ('phone', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'pair'),
#  ('up', 'of', 'a', 'pair', 'of'),
#  ('of', 'a', 'pair', 'of', 'scissors'),
#  ('a', 'pair', 'of', 'scissors', 'on'),
#  ('pair', 'of', 'scissors', 'on', 'a'),
#  ('of', 'scissors', 'on', 'a', 'table'),
#  ('scissors', 'on', 'a', 'table', 'a'),
#  ('on', 'a', 'table', 'a', 'couple'),
#  ('a', 'table', 'a', 'couple', 'of'),
#  ('table', 'a', 'couple', 'of', 'animals'),
#  ('a', 'couple', 'of', 'animals', 'that'),
#  ('couple', 'of', 'animals', 'that', 'are'),
#  ('of', 'animals', 'that', 'are', 'in'),
#  ('animals', 'that', 'are', 'in', 'the'),
#  ('that', 'are', 'in', 'the', 'water'),
#  ('are', 'in', 'the', 'water', 'a'),
#  ('in', 'the', 'water', 'a', 'large'),
#  ('the', 'water', 'a', 'large', 'long'),
#  ('water', 'a', 'large', 'long', 'train'),
#  ('a', 'large', 'long', 'train', 'on'),
#  ('large', 'long', 'train', 'on', 'a'),
#  ('long', 'train', 'on', 'a', 'steel'),
#  ('train', 'on', 'a', 'steel', 'track'),
#  ('on', 'a', 'steel', 'track', 'a'),
#  ('a', 'steel', 'track', 'a', 'man'),
#  ('steel', 'track', 'a', 'man', 'holding'),
#  ('track', 'a', 'man', 'holding', 'a'),
#  ('a', 'man', 'holding', 'a', 'cell'),
#  ('man', 'holding', 'a', 'cell', 'phone'),
#  ('holding', 'a', 'cell', 'phone', 'up'),
#  ('a', 'cell', 'phone', 'up', 'to'),
#  ('cell', 'phone', 'up', 'to', 'his'),
#  ('phone', 'up', 'to', 'his', 'ear'),
#  ('up', 'to', 'his', 'ear', 'a'),
#  ('to', 'his', 'ear', 'a', 'herd'),
#  ('his', 'ear', 'a', 'herd', 'of'),
#  ('ear', 'a', 'herd', 'of', 'sheep'),
#  ('a', 'herd', 'of', 'sheep', 'walking'),
#  ('herd', 'of', 'sheep', 'walking', 'across'),
#  ('of', 'sheep', 'walking', 'across', 'a'),
#  ('sheep', 'walking', 'across', 'a', 'snow'),
#  ('walking', 'across', 'a', 'snow', 'covered'),
#  ('across', 'a', 'snow', 'covered', 'field'),
#  ('a', 'snow', 'covered', 'field', 'a'),
#  ('snow', 'covered', 'field', 'a', 'view'),
#  ('covered', 'field', 'a', 'view', 'of'),
#  ('field', 'a', 'view', 'of', 'a'),
#  ('a', 'view', 'of', 'a', 'building'),
#  ('view', 'of', 'a', 'building', 'with'),
#  ('of', 'a', 'building', 'with', 'a'),
#  ('a', 'building', 'with', 'a', 'clock'),
#  ('building', 'with', 'a', 'clock', 'on'),
#  ('with', 'a', 'clock', 'on', 'it'),
#  ('a', 'clock', 'on', 'it', 'a'),
#  ('clock', 'on', 'it', 'a', 'close'),
#  ('on', 'it', 'a', 'close', 'up'),
#  ('it', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'red'),
#  ('up', 'of', 'a', 'red', 'stop'),
#  ('of', 'a', 'red', 'stop', 'sign'),
#  ('a', 'red', 'stop', 'sign', 'a'),
#  ('red', 'stop', 'sign', 'a', 'close'),
#  ('stop', 'sign', 'a', 'close', 'up'),
#  ('sign', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'clock'),
#  ('up', 'of', 'a', 'clock', 'on'),
#  ('of', 'a', 'clock', 'on', 'a'),
#  ('a', 'clock', 'on', 'a', 'wall'),
#  ('clock', 'on', 'a', 'wall', 'a'),
#  ('on', 'a', 'wall', 'a', 'group'),
#  ('a', 'wall', 'a', 'group', 'of'),
#  ('wall', 'a', 'group', 'of', 'people'),
#  ('a', 'group', 'of', 'people', 'standing'),
#  ('group', 'of', 'people', 'standing', 'around'),
#  ('of', 'people', 'standing', 'around', 'a'),
#  ('people', 'standing', 'around', 'a', 'giraffe'),
#  ('standing', 'around', 'a', 'giraffe', 'a'),
#  ('around', 'a', 'giraffe', 'a', 'clock'),
#  ('a', 'giraffe', 'a', 'clock', 'hanging'),
#  ('giraffe', 'a', 'clock', 'hanging', 'from'),
#  ('a', 'clock', 'hanging', 'from', 'a'),
#  ('clock', 'hanging', 'from', 'a', 'ceiling'),
#  ('hanging', 'from', 'a', 'ceiling', 'in'),
#  ('from', 'a', 'ceiling', 'in', 'a'),
#  ('a', 'ceiling', 'in', 'a', 'room'),
#  ('ceiling', 'in', 'a', 'room', 'a'),
#  ('in', 'a', 'room', 'a', 'black'),
#  ('a', 'room', 'a', 'black', 'and'),
#  ('room', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'photo'),
#  ('black', 'and', 'white', 'photo', 'of'),
#  ('and', 'white', 'photo', 'of', 'a'),
#  ('white', 'photo', 'of', 'a', 'vase'),
#  ('photo', 'of', 'a', 'vase', 'of'),
#  ('of', 'a', 'vase', 'of', 'flowers'),
#  ('a', 'vase', 'of', 'flowers', 'a'),
#  ('vase', 'of', 'flowers', 'a', 'kite'),
#  ('of', 'flowers', 'a', 'kite', 'that'),
#  ('flowers', 'a', 'kite', 'that', 'is'),
#  ('a', 'kite', 'that', 'is', 'flying'),
#  ('kite', 'that', 'is', 'flying', 'in'),
#  ('that', 'is', 'flying', 'in', 'the'),
#  ('is', 'flying', 'in', 'the', 'sky'),
#  ('flying', 'in', 'the', 'sky', 'a'),
#  ('in', 'the', 'sky', 'a', 'row'),
#  ('the', 'sky', 'a', 'row', 'of'),
#  ('sky', 'a', 'row', 'of', 'white'),
#  ('a', 'row', 'of', 'white', 'and'),
#  ('row', 'of', 'white', 'and', 'red'),
#  ('of', 'white', 'and', 'red', 'vases'),
#  ('white', 'and', 'red', 'vases', 'on'),
#  ('and', 'red', 'vases', 'on', 'display'),
#  ('red', 'vases', 'on', 'display', 'a'),
#  ('vases', 'on', 'display', 'a', 'close'),
#  ('on', 'display', 'a', 'close', 'up'),
#  ('display', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'toothbrush'),
#  ('up', 'of', 'a', 'toothbrush', 'in'),
#  ('of', 'a', 'toothbrush', 'in', 'a'),
#  ('a', 'toothbrush', 'in', 'a', 'cup'),
#  ('toothbrush', 'in', 'a', 'cup', 'a'),
#  ('in', 'a', 'cup', 'a', 'large'),
#  ('a', 'cup', 'a', 'large', 'building'),
#  ('cup', 'a', 'large', 'building', 'with'),
#  ('a', 'large', 'building', 'with', 'a'),
#  ('large', 'building', 'with', 'a', 'clock'),
#  ('building', 'with', 'a', 'clock', 'on'),
#  ('with', 'a', 'clock', 'on', 'it'),
#  ('a', 'clock', 'on', 'it', 'a'),
#  ('clock', 'on', 'it', 'a', 'close'),
#  ('on', 'it', 'a', 'close', 'up'),
#  ('it', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'red'),
#  ('up', 'of', 'a', 'red', 'fire'),
#  ('of', 'a', 'red', 'fire', 'hydrant'),
#  ('a', 'red', 'fire', 'hydrant', 'a'),
#  ('red', 'fire', 'hydrant', 'a', 'black'),
#  ('fire', 'hydrant', 'a', 'black', 'and'),
#  ('hydrant', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'photo'),
#  ('black', 'and', 'white', 'photo', 'of'),
#  ('and', 'white', 'photo', 'of', 'a'),
#  ('white', 'photo', 'of', 'a', 'television'),
#  ('photo', 'of', 'a', 'television', 'screen'),
#  ('of', 'a', 'television', 'screen', 'a'),
#  ('a', 'television', 'screen', 'a', 'smart'),
#  ('television', 'screen', 'a', 'smart', 'phone'),
#  ('screen', 'a', 'smart', 'phone', 'sitting'),
#  ('a', 'smart', 'phone', 'sitting', 'on'),
#  ('smart', 'phone', 'sitting', 'on', 'top'),
#  ('phone', 'sitting', 'on', 'top', 'of'),
#  ('sitting', 'on', 'top', 'of', 'a'),
#  ('on', 'top', 'of', 'a', 'wooden'),
#  ('top', 'of', 'a', 'wooden', 'table'),
#  ('of', 'a', 'wooden', 'table', 'a'),
#  ('a', 'wooden', 'table', 'a', 'picture'),
#  ('wooden', 'table', 'a', 'picture', 'of'),
#  ('table', 'a', 'picture', 'of', 'a'),
#  ('a', 'picture', 'of', 'a', 'person'),
#  ('picture', 'of', 'a', 'person', 'on'),
#  ('of', 'a', 'person', 'on', 'a'),
#  ('a', 'person', 'on', 'a', 'surfboard'),
#  ('person', 'on', 'a', 'surfboard', 'a'),
#  ('on', 'a', 'surfboard', 'a', 'black'),
#  ('a', 'surfboard', 'a', 'black', 'and'),
#  ('surfboard', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'photo'),
#  ('black', 'and', 'white', 'photo', 'of'),
#  ('and', 'white', 'photo', 'of', 'a'),
#  ('white', 'photo', 'of', 'a', 'man'),
#  ('photo', 'of', 'a', 'man', 'and'),
#  ('of', 'a', 'man', 'and', 'a'),
#  ('a', 'man', 'and', 'a', 'woman'),
#  ('man', 'and', 'a', 'woman', 'a'),
#  ('and', 'a', 'woman', 'a', 'view'),
#  ('a', 'woman', 'a', 'view', 'of'),
#  ('woman', 'a', 'view', 'of', 'a'),
#  ('a', 'view', 'of', 'a', 'mountain'),
#  ('view', 'of', 'a', 'mountain', 'range'),
#  ('of', 'a', 'mountain', 'range', 'from'),
#  ('a', 'mountain', 'range', 'from', 'the'),
#  ('mountain', 'range', 'from', 'the', 'ground'),
#  ('range', 'from', 'the', 'ground', 'a'),
#  ('from', 'the', 'ground', 'a', 'person'),
#  ('the', 'ground', 'a', 'person', 'on'),
#  ('ground', 'a', 'person', 'on', 'a'),
#  ('a', 'person', 'on', 'a', 'surfboard'),
#  ('person', 'on', 'a', 'surfboard', 'in'),
#  ('on', 'a', 'surfboard', 'in', 'the'),
#  ('a', 'surfboard', 'in', 'the', 'water'),
#  ('surfboard', 'in', 'the', 'water', 'a'),
#  ('in', 'the', 'water', 'a', 'black'),
#  ('the', 'water', 'a', 'black', 'and'),
#  ('water', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'photo'),
#  ('black', 'and', 'white', 'photo', 'of'),
#  ('and', 'white', 'photo', 'of', 'a'),
#  ('white', 'photo', 'of', 'a', 'man'),
#  ('photo', 'of', 'a', 'man', 'in'),
#  ('of', 'a', 'man', 'in', 'a'),
#  ('a', 'man', 'in', 'a', 'suit'),
#  ('man', 'in', 'a', 'suit', 'a'),
#  ('in', 'a', 'suit', 'a', 'bunch'),
#  ('a', 'suit', 'a', 'bunch', 'of'),
#  ('suit', 'a', 'bunch', 'of', 'snow'),
#  ('a', 'bunch', 'of', 'snow', 'covered'),
#  ('bunch', 'of', 'snow', 'covered', 'trees'),
#  ('of', 'snow', 'covered', 'trees', 'in'),
#  ('snow', 'covered', 'trees', 'in', 'the'),
#  ('covered', 'trees', 'in', 'the', 'snow'),
#  ('trees', 'in', 'the', 'snow', 'a'),
#  ('in', 'the', 'snow', 'a', 'woman'),
#  ('the', 'snow', 'a', 'woman', 'is'),
#  ('snow', 'a', 'woman', 'is', 'sitting'),
#  ('a', 'woman', 'is', 'sitting', 'on'),
#  ('woman', 'is', 'sitting', 'on', 'a'),
#  ('is', 'sitting', 'on', 'a', 'bed'),
#  ('sitting', 'on', 'a', 'bed', 'in'),
#  ('on', 'a', 'bed', 'in', 'a'),
#  ('a', 'bed', 'in', 'a', 'room'),
#  ('bed', 'in', 'a', 'room', 'a'),
#  ('in', 'a', 'room', 'a', 'bunch'),
#  ('a', 'room', 'a', 'bunch', 'of'),
#  ('room', 'a', 'bunch', 'of', 'umbrellas'),
#  ('a', 'bunch', 'of', 'umbrellas', 'that'),
#  ('bunch', 'of', 'umbrellas', 'that', 'are'),
#  ('of', 'umbrellas', 'that', 'are', 'in'),
#  ('umbrellas', 'that', 'are', 'in', 'the'),
#  ('that', 'are', 'in', 'the', 'air'),
#  ('are', 'in', 'the', 'air', 'a'),
#  ('in', 'the', 'air', 'a', 'black'),
#  ('the', 'air', 'a', 'black', 'and'),
#  ('air', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'photo'),
#  ('black', 'and', 'white', 'photo', 'of'),
#  ('and', 'white', 'photo', 'of', 'a'),
#  ('white', 'photo', 'of', 'a', 'bedroom'),
#  ('photo', 'of', 'a', 'bedroom', 'a'),
#  ('of', 'a', 'bedroom', 'a', 'close'),
#  ('a', 'bedroom', 'a', 'close', 'up'),
#  ('bedroom', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'person'),
#  ('up', 'of', 'a', 'person', 'holding'),
#  ('of', 'a', 'person', 'holding', 'a'),
#  ('a', 'person', 'holding', 'a', 'frisbee'),
#  ('person', 'holding', 'a', 'frisbee', 'a'),
#  ('holding', 'a', 'frisbee', 'a', 'red'),
#  ('a', 'frisbee', 'a', 'red', 'fire'),
#  ('frisbee', 'a', 'red', 'fire', 'hydrant'),
#  ('a', 'red', 'fire', 'hydrant', 'sitting'),
#  ('red', 'fire', 'hydrant', 'sitting', 'in'),
#  ('fire', 'hydrant', 'sitting', 'in', 'the'),
#  ('hydrant', 'sitting', 'in', 'the', 'middle'),
#  ('sitting', 'in', 'the', 'middle', 'of'),
#  ('in', 'the', 'middle', 'of', 'a'),
#  ('the', 'middle', 'of', 'a', 'forest'),
#  ('middle', 'of', 'a', 'forest', 'a'),
#  ('of', 'a', 'forest', 'a', 'train'),
#  ('a', 'forest', 'a', 'train', 'traveling'),
#  ('forest', 'a', 'train', 'traveling', 'through'),
#  ('a', 'train', 'traveling', 'through', 'a'),
#  ('train', 'traveling', 'through', 'a', 'lush'),
#  ('traveling', 'through', 'a', 'lush', 'green'),
#  ('through', 'a', 'lush', 'green', 'forest'),
#  ('a', 'lush', 'green', 'forest', 'a'),
#  ('lush', 'green', 'forest', 'a', 'black'),
#  ('green', 'forest', 'a', 'black', 'and'),
#  ('forest', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'photo'),
#  ('black', 'and', 'white', 'photo', 'of'),
#  ('and', 'white', 'photo', 'of', 'a'),
#  ('white', 'photo', 'of', 'a', 'window'),
#  ('photo', 'of', 'a', 'window', 'a'),
#  ('of', 'a', 'window', 'a', 'close'),
#  ('a', 'window', 'a', 'close', 'up'),
#  ('window', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'person'),
#  ('up', 'of', 'a', 'person', 'holding'),
#  ('of', 'a', 'person', 'holding', 'a'),
#  ('a', 'person', 'holding', 'a', 'pair'),
#  ('person', 'holding', 'a', 'pair', 'of'),
#  ('holding', 'a', 'pair', 'of', 'scissors'),
#  ('a', 'pair', 'of', 'scissors', 'a'),
#  ('pair', 'of', 'scissors', 'a', 'view'),
#  ('of', 'scissors', 'a', 'view', 'of'),
#  ('scissors', 'a', 'view', 'of', 'a'),
#  ('a', 'view', 'of', 'a', 'window'),
#  ('view', 'of', 'a', 'window', 'in'),
#  ('of', 'a', 'window', 'in', 'a'),
#  ('a', 'window', 'in', 'a', 'dark'),
#  ('window', 'in', 'a', 'dark', 'room'),
#  ('in', 'a', 'dark', 'room', 'a'),
#  ('a', 'dark', 'room', 'a', 'person'),
#  ('dark', 'room', 'a', 'person', 'riding'),
#  ('room', 'a', 'person', 'riding', 'a'),
#  ('a', 'person', 'riding', 'a', 'surf'),
#  ('person', 'riding', 'a', 'surf', 'board'),
#  ('riding', 'a', 'surf', 'board', 'on'),
#  ('a', 'surf', 'board', 'on', 'a'),
#  ('surf', 'board', 'on', 'a', 'wave'),
#  ('board', 'on', 'a', 'wave', 'a'),
#  ('on', 'a', 'wave', 'a', 'woman'),
#  ('a', 'wave', 'a', 'woman', 'walking'),
#  ('wave', 'a', 'woman', 'walking', 'down'),
#  ('a', 'woman', 'walking', 'down', 'a'),
#  ('woman', 'walking', 'down', 'a', 'street'),
#  ('walking', 'down', 'a', 'street', 'holding'),
#  ('down', 'a', 'street', 'holding', 'an'),
#  ('a', 'street', 'holding', 'an', 'umbrella'),
#  ('street', 'holding', 'an', 'umbrella', 'a'),
#  ('holding', 'an', 'umbrella', 'a', 'black'),
#  ('an', 'umbrella', 'a', 'black', 'and'),
#  ('umbrella', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'photo'),
#  ('black', 'and', 'white', 'photo', 'of'),
#  ('and', 'white', 'photo', 'of', 'a'),
#  ('white', 'photo', 'of', 'a', 'bathroom'),
#  ('photo', 'of', 'a', 'bathroom', 'mirror'),
#  ('of', 'a', 'bathroom', 'mirror', 'a'),
#  ('a', 'bathroom', 'mirror', 'a', 'black'),
#  ('bathroom', 'mirror', 'a', 'black', 'and'),
#  ('mirror', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'image'),
#  ('black', 'and', 'white', 'image', 'of'),
#  ('and', 'white', 'image', 'of', 'a'),
#  ('white', 'image', 'of', 'a', 'vase'),
#  ('image', 'of', 'a', 'vase', 'with'),
#  ('of', 'a', 'vase', 'with', 'flowers'),
#  ('a', 'vase', 'with', 'flowers', 'in'),
#  ('vase', 'with', 'flowers', 'in', 'it'),
#  ('with', 'flowers', 'in', 'it', 'a'),
#  ('flowers', 'in', 'it', 'a', 'view'),
#  ('in', 'it', 'a', 'view', 'of'),
#  ('it', 'a', 'view', 'of', 'a'),
#  ('a', 'view', 'of', 'a', 'window'),
#  ('view', 'of', 'a', 'window', 'in'),
#  ('of', 'a', 'window', 'in', 'a'),
#  ('a', 'window', 'in', 'a', 'dark'),
#  ('window', 'in', 'a', 'dark', 'room'),
#  ('in', 'a', 'dark', 'room', 'a'),
#  ('a', 'dark', 'room', 'a', 'close'),
#  ('dark', 'room', 'a', 'close', 'up'),
#  ('room', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'person'),
#  ('up', 'of', 'a', 'person', 'holding'),
#  ('of', 'a', 'person', 'holding', 'a'),
#  ('a', 'person', 'holding', 'a', 'cell'),
#  ('person', 'holding', 'a', 'cell', 'phone'),
#  ('holding', 'a', 'cell', 'phone', 'a'),
#  ('a', 'cell', 'phone', 'a', 'woman'),
#  ('cell', 'phone', 'a', 'woman', 'taking'),
#  ('phone', 'a', 'woman', 'taking', 'a'),
#  ('a', 'woman', 'taking', 'a', 'picture'),
#  ('woman', 'taking', 'a', 'picture', 'of'),
#  ('taking', 'a', 'picture', 'of', 'herself'),
#  ('a', 'picture', 'of', 'herself', 'in'),
#  ('picture', 'of', 'herself', 'in', 'a'),
#  ('of', 'herself', 'in', 'a', 'mirror'),
#  ('herself', 'in', 'a', 'mirror', 'a'),
#  ('in', 'a', 'mirror', 'a', 'black'),
#  ('a', 'mirror', 'a', 'black', 'and'),
#  ('mirror', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'image'),
#  ('black', 'and', 'white', 'image', 'of'),
#  ('and', 'white', 'image', 'of', 'a'),
#  ('white', 'image', 'of', 'a', 'vase'),
#  ('image', 'of', 'a', 'vase', 'with'),
#  ('of', 'a', 'vase', 'with', 'a'),
#  ('a', 'vase', 'with', 'a', 'flower'),
#  ('vase', 'with', 'a', 'flower', 'in'),
#  ('with', 'a', 'flower', 'in', 'it'),
#  ('a', 'flower', 'in', 'it', 'a'),
#  ('flower', 'in', 'it', 'a', 'close'),
#  ('in', 'it', 'a', 'close', 'up'),
#  ('it', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'person'),
#  ('up', 'of', 'a', 'person', 'holding'),
#  ('of', 'a', 'person', 'holding', 'a'),
#  ('a', 'person', 'holding', 'a', 'cell'),
#  ('person', 'holding', 'a', 'cell', 'phone'),
#  ('holding', 'a', 'cell', 'phone', 'a'),
#  ('a', 'cell', 'phone', 'a', 'close'),
#  ('cell', 'phone', 'a', 'close', 'up'),
#  ('phone', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'person'),
#  ('up', 'of', 'a', 'person', 'holding'),
#  ('of', 'a', 'person', 'holding', 'an'),
#  ('a', 'person', 'holding', 'an', 'umbrella'),
#  ('person', 'holding', 'an', 'umbrella', 'a'),
#  ('holding', 'an', 'umbrella', 'a', 'black'),
#  ('an', 'umbrella', 'a', 'black', 'and'),
#  ('umbrella', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'photo'),
#  ('black', 'and', 'white', 'photo', 'of'),
#  ('and', 'white', 'photo', 'of', 'a'),
#  ('white', 'photo', 'of', 'a', 'person'),
#  ('photo', 'of', 'a', 'person', 'taking'),
#  ('of', 'a', 'person', 'taking', 'a'),
#  ('a', 'person', 'taking', 'a', 'picture'),
#  ('person', 'taking', 'a', 'picture', 'a'),
#  ('taking', 'a', 'picture', 'a', 'close'),
#  ('a', 'picture', 'a', 'close', 'up'),
#  ('picture', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'black'),
#  ('up', 'of', 'a', 'black', 'and'),
#  ('of', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'clock'),
#  ('black', 'and', 'white', 'clock', 'a'),
#  ('and', 'white', 'clock', 'a', 'group'),
#  ('white', 'clock', 'a', 'group', 'of'),
#  ('clock', 'a', 'group', 'of', 'people'),
#  ('a', 'group', 'of', 'people', 'standing'),
#  ('group', 'of', 'people', 'standing', 'in'),
#  ('of', 'people', 'standing', 'in', 'front'),
#  ('people', 'standing', 'in', 'front', 'of'),
#  ('standing', 'in', 'front', 'of', 'a'),
#  ('in', 'front', 'of', 'a', 'tall'),
#  ('front', 'of', 'a', 'tall', 'building'),
#  ('of', 'a', 'tall', 'building', 'a'),
#  ('a', 'tall', 'building', 'a', 'close'),
#  ('tall', 'building', 'a', 'close', 'up'),
#  ('building', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'book'),
#  ('up', 'of', 'a', 'book', 'on'),
#  ('of', 'a', 'book', 'on', 'a'),
#  ('a', 'book', 'on', 'a', 'table'),
#  ('book', 'on', 'a', 'table', 'a'),
#  ('on', 'a', 'table', 'a', 'bunch'),
#  ('a', 'table', 'a', 'bunch', 'of'),
#  ('table', 'a', 'bunch', 'of', 'vases'),
#  ('a', 'bunch', 'of', 'vases', 'that'),
#  ('bunch', 'of', 'vases', 'that', 'have'),
#  ('of', 'vases', 'that', 'have', 'flowers'),
#  ('vases', 'that', 'have', 'flowers', 'in'),
#  ('that', 'have', 'flowers', 'in', 'them'),
#  ('have', 'flowers', 'in', 'them', 'a'),
#  ('flowers', 'in', 'them', 'a', 'view'),
#  ('in', 'them', 'a', 'view', 'of'),
#  ('them', 'a', 'view', 'of', 'a'),
#  ('a', 'view', 'of', 'a', 'room'),
#  ('view', 'of', 'a', 'room', 'with'),
#  ('of', 'a', 'room', 'with', 'a'),
#  ('a', 'room', 'with', 'a', 'bed'),
#  ('room', 'with', 'a', 'bed', 'and'),
#  ('with', 'a', 'bed', 'and', 'a'),
#  ('a', 'bed', 'and', 'a', 'window'),
#  ('bed', 'and', 'a', 'window', 'a'),
#  ('and', 'a', 'window', 'a', 'view'),
#  ('a', 'window', 'a', 'view', 'of'),
#  ('window', 'a', 'view', 'of', 'a'),
#  ('a', 'view', 'of', 'a', 'city'),
#  ('view', 'of', 'a', 'city', 'street'),
#  ('of', 'a', 'city', 'street', 'with'),
#  ('a', 'city', 'street', 'with', 'a'),
#  ('city', 'street', 'with', 'a', 'lot'),
#  ('street', 'with', 'a', 'lot', 'of'),
#  ('with', 'a', 'lot', 'of', 'snow'),
#  ('a', 'lot', 'of', 'snow', 'a'),
#  ('lot', 'of', 'snow', 'a', 'close'),
#  ('of', 'snow', 'a', 'close', 'up'),
#  ('snow', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'street'),
#  ('up', 'of', 'a', 'street', 'sign'),
#  ('of', 'a', 'street', 'sign', 'with'),
#  ('a', 'street', 'sign', 'with', 'a'),
#  ('street', 'sign', 'with', 'a', 'sky'),
#  ('sign', 'with', 'a', 'sky', 'background'),
#  ('with', 'a', 'sky', 'background', 'a'),
#  ('a', 'sky', 'background', 'a', 'large'),
#  ('sky', 'background', 'a', 'large', 'building'),
#  ('background', 'a', 'large', 'building', 'with'),
#  ('a', 'large', 'building', 'with', 'a'),
#  ('large', 'building', 'with', 'a', 'clock'),
#  ('building', 'with', 'a', 'clock', 'on'),
#  ('with', 'a', 'clock', 'on', 'it'),
#  ('a', 'clock', 'on', 'it', 'a'),
#  ('clock', 'on', 'it', 'a', 'view'),
#  ('on', 'it', 'a', 'view', 'of'),
#  ('it', 'a', 'view', 'of', 'a'),
#  ('a', 'view', 'of', 'a', 'city'),
#  ('view', 'of', 'a', 'city', 'street'),
#  ('of', 'a', 'city', 'street', 'at'),
#  ('a', 'city', 'street', 'at', 'night'),
#  ('city', 'street', 'at', 'night', 'a'),
#  ('street', 'at', 'night', 'a', 'group'),
#  ('at', 'night', 'a', 'group', 'of'),
#  ('night', 'a', 'group', 'of', 'people'),
#  ('a', 'group', 'of', 'people', 'standing'),
#  ('group', 'of', 'people', 'standing', 'around'),
#  ('of', 'people', 'standing', 'around', 'a'),
#  ('people', 'standing', 'around', 'a', 'table'),
#  ('standing', 'around', 'a', 'table', 'a'),
#  ('around', 'a', 'table', 'a', 'train'),
#  ('a', 'table', 'a', 'train', 'traveling'),
#  ('table', 'a', 'train', 'traveling', 'through'),
#  ('a', 'train', 'traveling', 'through', 'a'),
#  ('train', 'traveling', 'through', 'a', 'snow'),
#  ('traveling', 'through', 'a', 'snow', 'covered'),
#  ('through', 'a', 'snow', 'covered', 'forest'),
#  ('a', 'snow', 'covered', 'forest', 'a'),
#  ('snow', 'covered', 'forest', 'a', 'close'),
#  ('covered', 'forest', 'a', 'close', 'up'),
#  ('forest', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'red'),
#  ('up', 'of', 'a', 'red', 'and'),
#  ('of', 'a', 'red', 'and', 'white'),
#  ('a', 'red', 'and', 'white', 'toothbrush'),
#  ('red', 'and', 'white', 'toothbrush', 'a'),
#  ('and', 'white', 'toothbrush', 'a', 'bunch'),
#  ('white', 'toothbrush', 'a', 'bunch', 'of'),
#  ('toothbrush', 'a', 'bunch', 'of', 'different'),
#  ('a', 'bunch', 'of', 'different', 'colored'),
#  ('bunch', 'of', 'different', 'colored', 'ties'),
#  ('of', 'different', 'colored', 'ties', 'on'),
#  ('different', 'colored', 'ties', 'on', 'a'),
#  ('colored', 'ties', 'on', 'a', 'table'),
#  ('ties', 'on', 'a', 'table', 'a'),
#  ('on', 'a', 'table', 'a', 'close'),
#  ('a', 'table', 'a', 'close', 'up'),
#  ('table', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'person'),
#  ('up', 'of', 'a', 'person', 'wearing'),
#  ('of', 'a', 'person', 'wearing', 'a'),
#  ('a', 'person', 'wearing', 'a', 'tie'),
#  ('person', 'wearing', 'a', 'tie', 'a'),
#  ('wearing', 'a', 'tie', 'a', 'large'),
#  ('a', 'tie', 'a', 'large', 'clock'),
#  ('tie', 'a', 'large', 'clock', 'mounted'),
#  ('a', 'large', 'clock', 'mounted', 'to'),
#  ('large', 'clock', 'mounted', 'to', 'the'),
#  ('clock', 'mounted', 'to', 'the', 'side'),
#  ('mounted', 'to', 'the', 'side', 'of'),
#  ('to', 'the', 'side', 'of', 'a'),
#  ('the', 'side', 'of', 'a', 'wall'),
#  ('side', 'of', 'a', 'wall', 'a'),
#  ('of', 'a', 'wall', 'a', 'close'),
#  ('a', 'wall', 'a', 'close', 'up'),
#  ('wall', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'vase'),
#  ('up', 'of', 'a', 'vase', 'with'),
#  ('of', 'a', 'vase', 'with', 'flowers'),
#  ('a', 'vase', 'with', 'flowers', 'in'),
#  ('vase', 'with', 'flowers', 'in', 'it'),
#  ('with', 'flowers', 'in', 'it', 'a'),
#  ('flowers', 'in', 'it', 'a', 'large'),
#  ('in', 'it', 'a', 'large', 'white'),
#  ('it', 'a', 'large', 'white', 'building'),
#  ('a', 'large', 'white', 'building', 'with'),
#  ('large', 'white', 'building', 'with', 'a'),
#  ('white', 'building', 'with', 'a', 'large'),
#  ('building', 'with', 'a', 'large', 'window'),
#  ('with', 'a', 'large', 'window', 'a'),
#  ('a', 'large', 'window', 'a', 'black'),
#  ('large', 'window', 'a', 'black', 'and'),
#  ('window', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'image'),
#  ('black', 'and', 'white', 'image', 'of'),
#  ('and', 'white', 'image', 'of', 'a'),
#  ('white', 'image', 'of', 'a', 'vase'),
#  ('image', 'of', 'a', 'vase', 'with'),
#  ('of', 'a', 'vase', 'with', 'flowers'),
#  ('a', 'vase', 'with', 'flowers', 'in'),
#  ('vase', 'with', 'flowers', 'in', 'it'),
#  ('with', 'flowers', 'in', 'it', 'a'),
#  ('flowers', 'in', 'it', 'a', 'white'),
#  ('in', 'it', 'a', 'white', 'and'),
#  ('it', 'a', 'white', 'and', 'red'),
#  ('a', 'white', 'and', 'red', 'bus'),
#  ('white', 'and', 'red', 'bus', 'parked'),
#  ('and', 'red', 'bus', 'parked', 'in'),
#  ('red', 'bus', 'parked', 'in', 'front'),
#  ('bus', 'parked', 'in', 'front', 'of'),
#  ('parked', 'in', 'front', 'of', 'a'),
#  ('in', 'front', 'of', 'a', 'building'),
#  ('front', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'bunch'),
#  ('a', 'building', 'a', 'bunch', 'of'),
#  ('building', 'a', 'bunch', 'of', 'different'),
#  ('a', 'bunch', 'of', 'different', 'colored'),
#  ('bunch', 'of', 'different', 'colored', 'ties'),
#  ('of', 'different', 'colored', 'ties', 'on'),
#  ('different', 'colored', 'ties', 'on', 'a'),
#  ('colored', 'ties', 'on', 'a', 'table'),
#  ('ties', 'on', 'a', 'table', 'a'),
#  ('on', 'a', 'table', 'a', 'person'),
#  ('a', 'table', 'a', 'person', 'cutting'),
#  ('table', 'a', 'person', 'cutting', 'a'),
#  ('a', 'person', 'cutting', 'a', 'piece'),
#  ('person', 'cutting', 'a', 'piece', 'of'),
#  ('cutting', 'a', 'piece', 'of', 'paper'),
#  ('a', 'piece', 'of', 'paper', 'with'),
#  ('piece', 'of', 'paper', 'with', 'scissors'),
#  ('of', 'paper', 'with', 'scissors', 'a'),
#  ('paper', 'with', 'scissors', 'a', 'large'),
#  ('with', 'scissors', 'a', 'large', 'building'),
#  ('scissors', 'a', 'large', 'building', 'with'),
#  ('a', 'large', 'building', 'with', 'a'),
#  ('large', 'building', 'with', 'a', 'large'),
#  ('building', 'with', 'a', 'large', 'clock'),
#  ('with', 'a', 'large', 'clock', 'tower'),
#  ('a', 'large', 'clock', 'tower', 'a'),
#  ('large', 'clock', 'tower', 'a', 'row'),
#  ('clock', 'tower', 'a', 'row', 'of'),
#  ('tower', 'a', 'row', 'of', 'wooden'),
#  ('a', 'row', 'of', 'wooden', 'benches'),
#  ('row', 'of', 'wooden', 'benches', 'sitting'),
#  ('of', 'wooden', 'benches', 'sitting', 'next'),
#  ('wooden', 'benches', 'sitting', 'next', 'to'),
#  ('benches', 'sitting', 'next', 'to', 'each'),
#  ('sitting', 'next', 'to', 'each', 'other'),
#  ('next', 'to', 'each', 'other', 'a'),
#  ('to', 'each', 'other', 'a', 'close'),
#  ('each', 'other', 'a', 'close', 'up'),
#  ('other', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'snow'),
#  ('up', 'of', 'a', 'snow', 'covered'),
#  ('of', 'a', 'snow', 'covered', 'ground'),
#  ('a', 'snow', 'covered', 'ground', 'a'),
#  ('snow', 'covered', 'ground', 'a', 'close'),
#  ('covered', 'ground', 'a', 'close', 'up'),
#  ('ground', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'an'),
#  ('close', 'up', 'of', 'an', 'orange'),
#  ('up', 'of', 'an', 'orange', 'on'),
#  ('of', 'an', 'orange', 'on', 'a'),
#  ('an', 'orange', 'on', 'a', 'plate'),
#  ('orange', 'on', 'a', 'plate', 'a'),
#  ('on', 'a', 'plate', 'a', 'large'),
#  ('a', 'plate', 'a', 'large', 'umbrella'),
#  ('plate', 'a', 'large', 'umbrella', 'sitting'),
#  ('a', 'large', 'umbrella', 'sitting', 'on'),
#  ('large', 'umbrella', 'sitting', 'on', 'top'),
#  ('umbrella', 'sitting', 'on', 'top', 'of'),
#  ('sitting', 'on', 'top', 'of', 'a'),
#  ('on', 'top', 'of', 'a', 'wooden'),
#  ('top', 'of', 'a', 'wooden', 'table'),
#  ('of', 'a', 'wooden', 'table', 'a'),
#  ('a', 'wooden', 'table', 'a', 'close'),
#  ('wooden', 'table', 'a', 'close', 'up'),
#  ('table', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'red'),
#  ('up', 'of', 'a', 'red', 'and'),
#  ('of', 'a', 'red', 'and', 'white'),
#  ('a', 'red', 'and', 'white', 'clock'),
#  ('red', 'and', 'white', 'clock', 'a'),
#  ('and', 'white', 'clock', 'a', 'picture'),
#  ('white', 'clock', 'a', 'picture', 'of'),
#  ('clock', 'a', 'picture', 'of', 'a'),
#  ('a', 'picture', 'of', 'a', 'stop'),
#  ('picture', 'of', 'a', 'stop', 'sign'),
#  ('of', 'a', 'stop', 'sign', 'in'),
#  ('a', 'stop', 'sign', 'in', 'the'),
#  ('stop', 'sign', 'in', 'the', 'dark'),
#  ('sign', 'in', 'the', 'dark', 'a'),
#  ('in', 'the', 'dark', 'a', 'street'),
#  ('the', 'dark', 'a', 'street', 'sign'),
#  ('dark', 'a', 'street', 'sign', 'with'),
#  ('a', 'street', 'sign', 'with', 'a'),
#  ('street', 'sign', 'with', 'a', 'building'),
#  ('sign', 'with', 'a', 'building', 'in'),
#  ('with', 'a', 'building', 'in', 'the'),
#  ('a', 'building', 'in', 'the', 'background'),
#  ('building', 'in', 'the', 'background', 'a'),
#  ('in', 'the', 'background', 'a', 'stop'),
#  ('the', 'background', 'a', 'stop', 'sign'),
#  ('background', 'a', 'stop', 'sign', 'that'),
#  ('a', 'stop', 'sign', 'that', 'is'),
#  ('stop', 'sign', 'that', 'is', 'on'),
#  ('sign', 'that', 'is', 'on', 'top'),
#  ('that', 'is', 'on', 'top', 'of'),
#  ('is', 'on', 'top', 'of', 'a'),
#  ('on', 'top', 'of', 'a', 'pole'),
#  ('top', 'of', 'a', 'pole', 'a'),
#  ('of', 'a', 'pole', 'a', 'close'),
#  ('a', 'pole', 'a', 'close', 'up'),
#  ('pole', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'vandalized'),
#  ('up', 'of', 'a', 'vandalized', 'stop'),
#  ('of', 'a', 'vandalized', 'stop', 'sign'),
#  ('a', 'vandalized', 'stop', 'sign', 'a'),
#  ('vandalized', 'stop', 'sign', 'a', 'man'),
#  ('stop', 'sign', 'a', 'man', 'sitting'),
#  ('sign', 'a', 'man', 'sitting', 'on'),
#  ('a', 'man', 'sitting', 'on', 'a'),
#  ('man', 'sitting', 'on', 'a', 'bench'),
#  ('sitting', 'on', 'a', 'bench', 'in'),
#  ('on', 'a', 'bench', 'in', 'front'),
#  ('a', 'bench', 'in', 'front', 'of'),
#  ('bench', 'in', 'front', 'of', 'a'),
#  ('in', 'front', 'of', 'a', 'building'),
#  ('front', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'sign'),
#  ('a', 'building', 'a', 'sign', 'on'),
#  ('building', 'a', 'sign', 'on', 'the'),
#  ('a', 'sign', 'on', 'the', 'side'),
#  ('sign', 'on', 'the', 'side', 'of'),
#  ('on', 'the', 'side', 'of', 'a'),
#  ('the', 'side', 'of', 'a', 'building'),
#  ('side', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'row'),
#  ('a', 'building', 'a', 'row', 'of'),
#  ('building', 'a', 'row', 'of', 'urinals'),
#  ('a', 'row', 'of', 'urinals', 'mounted'),
#  ('row', 'of', 'urinals', 'mounted', 'to'),
#  ('of', 'urinals', 'mounted', 'to', 'a'),
#  ('urinals', 'mounted', 'to', 'a', 'wall'),
#  ('mounted', 'to', 'a', 'wall', 'a'),
#  ('to', 'a', 'wall', 'a', 'black'),
#  ('a', 'wall', 'a', 'black', 'and'),
#  ('wall', 'a', 'black', 'and', 'white'),
#  ('a', 'black', 'and', 'white', 'photo'),
#  ('black', 'and', 'white', 'photo', 'of'),
#  ('and', 'white', 'photo', 'of', 'a'),
#  ('white', 'photo', 'of', 'a', 'pair'),
#  ('photo', 'of', 'a', 'pair', 'of'),
#  ('of', 'a', 'pair', 'of', 'scissors'),
#  ('a', 'pair', 'of', 'scissors', 'a'),
#  ('pair', 'of', 'scissors', 'a', 'stop'),
#  ('of', 'scissors', 'a', 'stop', 'sign'),
#  ('scissors', 'a', 'stop', 'sign', 'with'),
#  ('a', 'stop', 'sign', 'with', 'graffiti'),
#  ('stop', 'sign', 'with', 'graffiti', 'written'),
#  ('sign', 'with', 'graffiti', 'written', 'on'),
#  ('with', 'graffiti', 'written', 'on', 'it'),
#  ('graffiti', 'written', 'on', 'it', 'a'),
#  ('written', 'on', 'it', 'a', 'close'),
#  ('on', 'it', 'a', 'close', 'up'),
#  ('it', 'a', 'close', 'up', 'of'),
#  ('a', 'close', 'up', 'of', 'a'),
#  ('close', 'up', 'of', 'a', 'pair'),
#  ('up', 'of', 'a', 'pair', 'of'),
#  ('of', 'a', 'pair', 'of', 'scissors'),
#  ('a', 'pair', 'of', 'scissors', 'on'),
#  ('pair', 'of', 'scissors', 'on', 'a'),
#  ('of', 'scissors', 'on', 'a', 'table'),
#  ('scissors', 'on', 'a', 'table', 'a'),
#  ('on', 'a', 'table', 'a', 'man'),
#  ('a', 'table', 'a', 'man', 'sitting'),
#  ('table', 'a', 'man', 'sitting', 'on'),
#  ('a', 'man', 'sitting', 'on', 'a'),
#  ('man', 'sitting', 'on', 'a', 'bench'),
#  ('sitting', 'on', 'a', 'bench', 'under'),
#  ('on', 'a', 'bench', 'under', 'an'),
#  ('a', 'bench', 'under', 'an', 'umbrella'),
#  ('bench', 'under', 'an', 'umbrella', 'a'),
#  ('under', 'an', 'umbrella', 'a', 'sign'),
#  ('an', 'umbrella', 'a', 'sign', 'that'),
#  ('umbrella', 'a', 'sign', 'that', 'is'),
#  ('a', 'sign', 'that', 'is', 'on'),
#  ('sign', 'that', 'is', 'on', 'the'),
#  ('that', 'is', 'on', 'the', 'side'),
#  ('is', 'on', 'the', 'side', 'of'),
#  ('on', 'the', 'side', 'of', 'a'),
#  ('the', 'side', 'of', 'a', 'building'),
#  ('side', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'picture'),
#  ('a', 'building', 'a', 'picture', 'of'),
#  ('building', 'a', 'picture', 'of', 'a'),
#  ('a', 'picture', 'of', 'a', 'clock'),
#  ('picture', 'of', 'a', 'clock', 'on'),
#  ('of', 'a', 'clock', 'on', 'a'),
#  ('a', 'clock', 'on', 'a', 'wall'),
#  ('clock', 'on', 'a', 'wall', 'a'),
#  ('on', 'a', 'wall', 'a', 'clock'),
#  ('a', 'wall', 'a', 'clock', 'on'),
#  ('wall', 'a', 'clock', 'on', 'the'),
#  ('a', 'clock', 'on', 'the', 'wall'),
#  ('clock', 'on', 'the', 'wall', 'of'),
#  ('on', 'the', 'wall', 'of', 'a'),
#  ('the', 'wall', 'of', 'a', 'building'),
#  ('wall', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'man'),
#  ('a', 'building', 'a', 'man', 'standing'),
#  ('building', 'a', 'man', 'standing', 'in'),
#  ('a', 'man', 'standing', 'in', 'front'),
#  ('man', 'standing', 'in', 'front', 'of'),
#  ('standing', 'in', 'front', 'of', 'a'),
#  ('in', 'front', 'of', 'a', 'display'),
#  ('front', 'of', 'a', 'display', 'case'),
#  ('of', 'a', 'display', 'case', 'a'),
#  ('a', 'display', 'case', 'a', 'pair'),
#  ('display', 'case', 'a', 'pair', 'of'),
#  ('case', 'a', 'pair', 'of', 'scissors'),
#  ('a', 'pair', 'of', 'scissors', 'sitting'),
#  ('pair', 'of', 'scissors', 'sitting', 'on'),
#  ('of', 'scissors', 'sitting', 'on', 'top'),
#  ('scissors', 'sitting', 'on', 'top', 'of'),
#  ('sitting', 'on', 'top', 'of', 'a'),
#  ('on', 'top', 'of', 'a', 'table'),
#  ('top', 'of', 'a', 'table', 'a'),
#  ('of', 'a', 'table', 'a', 'window'),
#  ('a', 'table', 'a', 'window', 'with'),
#  ('table', 'a', 'window', 'with', 'a'),
#  ('a', 'window', 'with', 'a', 'picture'),
#  ('window', 'with', 'a', 'picture', 'of'),
#  ('with', 'a', 'picture', 'of', 'a'),
#  ('a', 'picture', 'of', 'a', 'clock'),
#  ('picture', 'of', 'a', 'clock', 'on'),
#  ('of', 'a', 'clock', 'on', 'it'),
#  ('a', 'clock', 'on', 'it', 'a'),
#  ('clock', 'on', 'it', 'a', 'group'),
#  ('on', 'it', 'a', 'group', 'of'),
#  ('it', 'a', 'group', 'of', 'people'),
#  ('a', 'group', 'of', 'people', 'standing'),
#  ('group', 'of', 'people', 'standing', 'in'),
#  ('of', 'people', 'standing', 'in', 'front'),
#  ('people', 'standing', 'in', 'front', 'of'),
#  ('standing', 'in', 'front', 'of', 'a'),
#  ('in', 'front', 'of', 'a', 'building'),
#  ('front', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'large'),
#  ('a', 'building', 'a', 'large', 'clock'),
#  ('building', 'a', 'large', 'clock', 'tower'),
#  ('a', 'large', 'clock', 'tower', 'with'),
#  ('large', 'clock', 'tower', 'with', 'a'),
#  ('clock', 'tower', 'with', 'a', 'sky'),
#  ('tower', 'with', 'a', 'sky', 'background'),
#  ('with', 'a', 'sky', 'background', 'a'),
#  ('a', 'sky', 'background', 'a', 'picture'),
#  ('sky', 'background', 'a', 'picture', 'of'),
#  ('background', 'a', 'picture', 'of', 'a'),
#  ('a', 'picture', 'of', 'a', 'person'),
#  ('picture', 'of', 'a', 'person', 'on'),
#  ('of', 'a', 'person', 'on', 'a'),
#  ('a', 'person', 'on', 'a', 'skateboard'),
#  ('person', 'on', 'a', 'skateboard', 'a'),
#  ('on', 'a', 'skateboard', 'a', 'clock'),
#  ('a', 'skateboard', 'a', 'clock', 'on'),
#  ('skateboard', 'a', 'clock', 'on', 'the'),
#  ('a', 'clock', 'on', 'the', 'side'),
#  ('clock', 'on', 'the', 'side', 'of'),
#  ('on', 'the', 'side', 'of', 'a'),
#  ('the', 'side', 'of', 'a', 'building'),
#  ('side', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'red'),
#  ('a', 'building', 'a', 'red', 'stop'),
#  ('building', 'a', 'red', 'stop', 'sign'),
#  ('a', 'red', 'stop', 'sign', 'sitting'),
#  ('red', 'stop', 'sign', 'sitting', 'on'),
#  ('stop', 'sign', 'sitting', 'on', 'the'),
#  ('sign', 'sitting', 'on', 'the', 'side'),
#  ('sitting', 'on', 'the', 'side', 'of'),
#  ('on', 'the', 'side', 'of', 'a'),
#  ('the', 'side', 'of', 'a', 'building'),
#  ('side', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'snow'),
#  ('a', 'building', 'a', 'snow', 'covered'),
#  ('building', 'a', 'snow', 'covered', 'street'),
#  ('a', 'snow', 'covered', 'street', 'in'),
#  ('snow', 'covered', 'street', 'in', 'the'),
#  ('covered', 'street', 'in', 'the', 'middle'),
#  ('street', 'in', 'the', 'middle', 'of'),
#  ('in', 'the', 'middle', 'of', 'a'),
#  ('the', 'middle', 'of', 'a', 'city'),
#  ('middle', 'of', 'a', 'city', 'a'),
#  ('of', 'a', 'city', 'a', 'bathroom'),
#  ('a', 'city', 'a', 'bathroom', 'with'),
#  ('city', 'a', 'bathroom', 'with', 'a'),
#  ('a', 'bathroom', 'with', 'a', 'shower'),
#  ('bathroom', 'with', 'a', 'shower', 'and'),
#  ('with', 'a', 'shower', 'and', 'a'),
#  ('a', 'shower', 'and', 'a', 'sink'),
#  ('shower', 'and', 'a', 'sink', 'a'),
#  ('and', 'a', 'sink', 'a', 'large'),
#  ('a', 'sink', 'a', 'large', 'clock'),
#  ('sink', 'a', 'large', 'clock', 'mounted'),
#  ('a', 'large', 'clock', 'mounted', 'to'),
#  ('large', 'clock', 'mounted', 'to', 'the'),
#  ('clock', 'mounted', 'to', 'the', 'side'),
#  ('mounted', 'to', 'the', 'side', 'of'),
#  ('to', 'the', 'side', 'of', 'a'),
#  ('the', 'side', 'of', 'a', 'building'),
#  ('side', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'bathroom'),
#  ('a', 'building', 'a', 'bathroom', 'with'),
#  ('building', 'a', 'bathroom', 'with', 'a'),
#  ('a', 'bathroom', 'with', 'a', 'sink'),
#  ('bathroom', 'with', 'a', 'sink', 'and'),
#  ('with', 'a', 'sink', 'and', 'a'),
#  ('a', 'sink', 'and', 'a', 'mirror'),
#  ('sink', 'and', 'a', 'mirror', 'a'),
#  ('and', 'a', 'mirror', 'a', 'bathroom'),
#  ('a', 'mirror', 'a', 'bathroom', 'with'),
#  ('mirror', 'a', 'bathroom', 'with', 'a'),
#  ('a', 'bathroom', 'with', 'a', 'large'),
#  ('bathroom', 'with', 'a', 'large', 'mirror'),
#  ('with', 'a', 'large', 'mirror', 'above'),
#  ('a', 'large', 'mirror', 'above', 'a'),
#  ('large', 'mirror', 'above', 'a', 'sink'),
#  ('mirror', 'above', 'a', 'sink', 'a'),
#  ('above', 'a', 'sink', 'a', 'bathroom'),
#  ('a', 'sink', 'a', 'bathroom', 'with'),
#  ('sink', 'a', 'bathroom', 'with', 'a'),
#  ('a', 'bathroom', 'with', 'a', 'toilet'),
#  ('bathroom', 'with', 'a', 'toilet', ','),
#  ('with', 'a', 'toilet', ',', 'sink'),
#  ('a', 'toilet', ',', 'sink', ','),
#  ('toilet', ',', 'sink', ',', 'and'),
#  (',', 'sink', ',', 'and', 'mirror'),
#  ('sink', ',', 'and', 'mirror', 'a'),
#  (',', 'and', 'mirror', 'a', 'sign'),
#  ('and', 'mirror', 'a', 'sign', 'that'),
#  ('mirror', 'a', 'sign', 'that', 'is'),
#  ('a', 'sign', 'that', 'is', 'on'),
#  ('sign', 'that', 'is', 'on', 'the'),
#  ('that', 'is', 'on', 'the', 'side'),
#  ('is', 'on', 'the', 'side', 'of'),
#  ('on', 'the', 'side', 'of', 'a'),
#  ('the', 'side', 'of', 'a', 'building'),
#  ('side', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'man'),
#  ('a', 'building', 'a', 'man', 'sitting'),
#  ('building', 'a', 'man', 'sitting', 'on'),
#  ('a', 'man', 'sitting', 'on', 'a'),
#  ('man', 'sitting', 'on', 'a', 'bench'),
#  ('sitting', 'on', 'a', 'bench', 'in'),
#  ('on', 'a', 'bench', 'in', 'a'),
#  ('a', 'bench', 'in', 'a', 'room'),
#  ('bench', 'in', 'a', 'room', 'a'),
#  ('in', 'a', 'room', 'a', 'pair'),
#  ('a', 'room', 'a', 'pair', 'of'),
#  ('room', 'a', 'pair', 'of', 'scissors'),
#  ('a', 'pair', 'of', 'scissors', 'sitting'),
#  ('pair', 'of', 'scissors', 'sitting', 'on'),
#  ('of', 'scissors', 'sitting', 'on', 'top'),
#  ('scissors', 'sitting', 'on', 'top', 'of'),
#  ('sitting', 'on', 'top', 'of', 'a'),
#  ('on', 'top', 'of', 'a', 'table'),
#  ('top', 'of', 'a', 'table', 'a'),
#  ('of', 'a', 'table', 'a', 'sign'),
#  ('a', 'table', 'a', 'sign', 'that'),
#  ('table', 'a', 'sign', 'that', 'reads'),
#  ('a', 'sign', 'that', 'reads', 'on'),
#  ('sign', 'that', 'reads', 'on', 'the'),
#  ('that', 'reads', 'on', 'the', 'side'),
#  ('reads', 'on', 'the', 'side', 'of'),
#  ('on', 'the', 'side', 'of', 'a'),
#  ('the', 'side', 'of', 'a', 'building'),
#  ('side', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'sign'),
#  ('a', 'building', 'a', 'sign', 'that'),
#  ('building', 'a', 'sign', 'that', 'is'),
#  ('a', 'sign', 'that', 'is', 'on'),
#  ('sign', 'that', 'is', 'on', 'the'),
#  ('that', 'is', 'on', 'the', 'side'),
#  ('is', 'on', 'the', 'side', 'of'),
#  ('on', 'the', 'side', 'of', 'a'),
#  ('the', 'side', 'of', 'a', 'building'),
#  ('side', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'clock'),
#  ('a', 'building', 'a', 'clock', 'on'),
#  ('building', 'a', 'clock', 'on', 'the'),
#  ('a', 'clock', 'on', 'the', 'side'),
#  ('clock', 'on', 'the', 'side', 'of'),
#  ('on', 'the', 'side', 'of', 'a'),
#  ('the', 'side', 'of', 'a', 'building'),
#  ('side', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'red'),
#  ('a', 'building', 'a', 'red', 'stop'),
#  ('building', 'a', 'red', 'stop', 'sign'),
#  ('a', 'red', 'stop', 'sign', 'sitting'),
#  ('red', 'stop', 'sign', 'sitting', 'on'),
#  ('stop', 'sign', 'sitting', 'on', 'the'),
#  ('sign', 'sitting', 'on', 'the', 'side'),
#  ('sitting', 'on', 'the', 'side', 'of'),
#  ('on', 'the', 'side', 'of', 'a'),
#  ('the', 'side', 'of', 'a', 'building'),
#  ('side', 'of', 'a', 'building', 'a'),
#  ('of', 'a', 'building', 'a', 'stop'),
#  ...]

# %% [markdown]
# And of course we can use it in conjunction with a `Counter` to find the most common n-grams in a text:

# %%
Counter(ngrams_for_sequence(3, open("textInspiration.txt").read())).most_common(20)
# Out:
# [((' ', 'a', ' '), 1204),
#  (('\n', 'a', ' '), 900),
#  ((' ', 'o', 'f'), 778),
#  (('o', 'f', ' '), 778),
#  (('i', 'n', 'g'), 546),
#  (('f', ' ', 'a'), 518),
#  (('n', 'g', ' '), 466),
#  (('o', 'n', ' '), 452),
#  (('a', ' ', 'c'), 406),
#  ((' ', 'o', 'n'), 369),
#  (('p', ' ', 'o'), 351),
#  ((' ', 'c', 'l'), 343),
#  (('c', 'l', 'o'), 343),
#  (('a', ' ', 'b'), 339),
#  ((' ', 's', 'i'), 308),
#  (('a', 'n', 'd'), 301),
#  (('d', 'i', 'n'), 297),
#  (('n', ' ', 'a'), 281),
#  ((' ', 'w', 'i'), 271),
#  (('u', 'p', ' '), 270)]

# %% [markdown]
# ## Markov models: what comes next?
#
# Now that we have the ability to find and record the n-grams in a text, it’s time to take our analysis one step further. The next question we’re going to try to answer is this: Given a particular n-gram in a text, what is most likely to come next?
#
# We can imagine the kind of algorithm we’ll need to extract this information from the text. It will look very similar to the code to find n-grams above, but it will need to keep track not just of the n-grams but also a list of all units (word, character, whatever) that *follow* those n-grams.
#
# Let’s do a quick example by hand. This is the same character-level order-2 n-gram analysis of the (very brief) text “condescendences” as above, but this time keeping track of all characters that follow each n-gram:
#
# | n-grams |	next? |
# | ------- | ----- |
# |co| n|
# |on| d|
# |nd| e, e|
# |de| s, n|
# |es| c, (end of text)|
# |sc| e|
# |ce| n, s|
# |en| d, c|
# |nc| e|

# %% [markdown]
# From this table, we can determine that while the n-gram `co` is followed by n 100% of the time, and while the n-gram `on` is followed by `d` 100% of the time, the n-gram `de` is followed by `s` 50% of the time, and `n` the rest of the time. Likewise, the n-gram `es` is followed by `c` 50% of the time, and followed by the end of the text the other 50% of the time.
#
# The easiest way to represent this model is with a dictionary whose keys are the n-grams and whose values are all of the possible "nexts." Here's what the Python code looks like to construct this model from a string. We'll use the special token `$` to represent the notion of the "end of text" in the table above.

# %% [markdown]
# The functions in the cell below generalize this to n-grams of arbitrary length (and use the special Python value `None` to indicate the end of a sequence). The `markov_model()` function creates an empty dictionary and takes an n-gram length and a sequence (which can be a string or a list) and calls the `add_to_model()` function on that sequence. The `add_to_model()` function does the same thing as the code above: iterates over every index of the sequence and grabs an n-gram of the desired length, adding keys and values to the dictionary as necessary.

# %%
def add_to_model(model, n, seq):
    # make a copy of seq and append None to the end
    seq = list(seq[:]) + [None]
    for i in range(len(seq)-n):
        # tuple because we're using it as a dict key!
        gram = tuple(seq[i:i+n])
        next_item = seq[i+n]            
        if gram not in model:
            model[gram] = []
        model[gram].append(next_item)

def markov_model(n, seq):
    model = {}
    add_to_model(model, n, seq)
    return model

# %% [markdown]
# Or an order 3 word-level Markov model of `textInspiration.txt`:

# %%
textInspiration_markov_model = markov_model(3, open("textInspiration.txt").read().split())

# %%
textInspiration_markov_model
# Out:
# {('a', 'black', 'and'): ['white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white'],
#  ('black', 'and', 'white'): ['photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'image',
#   'image',
#   'photo',
#   'clock',
#   'image',
#   'photo',
#   'photo',
#   'photo',
#   'background',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'background',
#   'background',
#   'photo',
#   'photo',
#   'image',
#   'photo',
#   'photo',
#   'cat',
#   'photo',
#   'bird',
#   'photo',
#   'photo',
#   'clock',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'image',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'image',
#   'photo',
#   'photo',
#   'background',
#   'blanket',
#   'photo'],
#  ('and', 'white', 'photo'): ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  ('white', 'photo', 'of'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'an',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('photo', 'of', 'a'): ['person',
#   'vase',
#   'television',
#   'man',
#   'man',
#   'bedroom',
#   'window',
#   'bathroom',
#   'person',
#   'pair',
#   'pair',
#   'building',
#   'plane',
#   'snowy',
#   'clock',
#   'pair',
#   'clock',
#   'pair',
#   'clock',
#   'traffic',
#   'stop',
#   'clock',
#   'bathroom',
#   'black',
#   'bird',
#   'man',
#   'clock',
#   'man',
#   'person',
#   'bathroom',
#   'man',
#   'man',
#   'man',
#   'man',
#   'man',
#   'man',
#   'bird',
#   'street',
#   'red',
#   'baseball'],
#  ('of', 'a', 'person'): ['holding',
#   'on',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'taking',
#   'wearing',
#   'on',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'wearing',
#   'holding',
#   'holding',
#   'wearing',
#   'holding',
#   'holding',
#   '"s"',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'on',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'flying',
#   'holding',
#   'holding',
#   'wearing',
#   'holding',
#   'holding',
#   'wearing',
#   'holding',
#   'holding',
#   'holding',
#   '"s"',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'holding',
#   'wearing'],
#  ('a', 'person', 'holding'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'an',
#   'a',
#   'an',
#   'a',
#   'a',
#   'an',
#   'a',
#   'an',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'an',
#   'a',
#   'a',
#   'an',
#   'an',
#   'an',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'an',
#   'a',
#   'a',
#   'a'],
#  ('person', 'holding', 'a'): ['cell',
#   'frisbee',
#   'pair',
#   'cell',
#   'cell',
#   'cell',
#   'surf',
#   'pair',
#   'box',
#   'skateboard',
#   'toothbrush',
#   'red',
#   'cell',
#   'remote',
#   'pair',
#   'surf',
#   'kite',
#   'nintendo',
#   'cell',
#   'skateboard',
#   'surf',
#   'cell',
#   'nintendo',
#   'nintendo',
#   'pair',
#   'pair',
#   'kite',
#   'tennis',
#   'knife',
#   'pair',
#   'pair',
#   'pair',
#   'cell',
#   'pair',
#   'banana',
#   'kite',
#   'kite',
#   'toothbrush',
#   'toothbrush',
#   'book',
#   'nintendo',
#   'pair'],
#  ('holding', 'a', 'cell'): ['phone',
#   'phone',
#   'phone',
#   'phone',
#   'phone',
#   'phone',
#   'phone',
#   'phone',
#   'phone',
#   'phone',
#   'phone',
#   'phone',
#   'phone',
#   'phone'],
#  ('a', 'cell', 'phone'): ['a',
#   'up',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('cell', 'phone', 'a'): ['close',
#   'woman',
#   'close',
#   'black',
#   'traffic',
#   'collage',
#   'pair',
#   'close',
#   'group',
#   'group',
#   'close',
#   'woman',
#   'man',
#   'room'],
#  ('phone', 'a', 'close'): ['up', 'up', 'up', 'up'],
#  ('a', 'close', 'up'): ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  ('close', 'up', 'of'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'an',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'an',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('up', 'of', 'a'): ['pair',
#   'red',
#   'clock',
#   'toothbrush',
#   'red',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'black',
#   'book',
#   'street',
#   'red',
#   'person',
#   'vase',
#   'snow',
#   'red',
#   'vandalized',
#   'pair',
#   'clock',
#   'vandalized',
#   'pair',
#   'pair',
#   'keyboard',
#   'pair',
#   'clock',
#   'person',
#   'person',
#   'clock',
#   'person',
#   'person',
#   'person',
#   'pair',
#   'person',
#   'pair',
#   'pair',
#   'clock',
#   'pair',
#   'person',
#   'mirror',
#   'cake',
#   'pair',
#   'pair',
#   'mirror',
#   'clock',
#   'clock',
#   'street',
#   'pair',
#   'street',
#   'clock',
#   'pair',
#   'street',
#   'stop',
#   'person',
#   'nintendo',
#   'pair',
#   'clock',
#   'box',
#   'red',
#   'clock',
#   'tennis',
#   'clock',
#   'vase',
#   'clock',
#   'pair',
#   'pair',
#   'vase',
#   'pair',
#   'window',
#   'blue',
#   'person',
#   'vase',
#   'clock',
#   'street',
#   'stop',
#   'white',
#   'red',
#   'clock',
#   'black',
#   'black',
#   'pair',
#   'pair',
#   'traffic',
#   'person',
#   'person',
#   'nintendo',
#   'pair',
#   'street',
#   'pair',
#   'cake',
#   'clock',
#   'cake',
#   'red',
#   'bed',
#   'tooth',
#   'blue',
#   'person',
#   'person',
#   'traffic',
#   'stop',
#   'vase',
#   'pair',
#   'colorful',
#   'pair',
#   'red',
#   'person',
#   'pair',
#   'body',
#   'person',
#   'tooth',
#   'traffic',
#   'window',
#   'tooth',
#   'pair',
#   'red',
#   'pair',
#   'pair',
#   'vase',
#   'vase',
#   'clock',
#   'clock',
#   'knife',
#   'clock',
#   'white',
#   'bunch',
#   'clock',
#   'person',
#   'person',
#   'pair',
#   'person',
#   'blue',
#   'vase',
#   'person',
#   'stuffed',
#   'blue',
#   'refrigerator',
#   'stop',
#   'person',
#   'black',
#   'pair',
#   'person',
#   'person',
#   'red',
#   'street',
#   'black',
#   'bird',
#   'white',
#   'person',
#   'tooth',
#   'white',
#   'clock',
#   'clock',
#   'laptop',
#   'street',
#   'plate',
#   'pair',
#   'vandalized',
#   'street',
#   'laptop',
#   'window',
#   'red',
#   'pair',
#   'vase',
#   'red',
#   'red',
#   'person',
#   'person',
#   'person',
#   'person',
#   'blue',
#   'mirror',
#   'person',
#   'mirror',
#   'small',
#   'pair',
#   'person',
#   'vase',
#   'clock',
#   'vase',
#   'person',
#   'person',
#   'person',
#   'toaster',
#   'person',
#   'person',
#   'cake',
#   'cake',
#   'pair',
#   'vase',
#   'pair',
#   'clock',
#   'person',
#   'white',
#   'cake',
#   'black',
#   'clock',
#   'person',
#   'person',
#   'pair',
#   'person',
#   'white',
#   'nintendo',
#   'clock',
#   'person',
#   'pair',
#   'pair',
#   'person',
#   'stuffed',
#   'pair',
#   'pair'],
#  ('of', 'a', 'pair'): ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  ('a', 'pair', 'of'): ['scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'red',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'red',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'skis',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors',
#   'scissors'],
#  ('pair', 'of', 'scissors'): ['on',
#   'a',
#   'a',
#   'on',
#   'sitting',
#   'sitting',
#   'a',
#   'a',
#   'a',
#   'sitting',
#   'on',
#   'a',
#   'a',
#   'on',
#   'sitting',
#   'on',
#   'on',
#   'sitting',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'sitting',
#   'a',
#   'sitting',
#   'sitting',
#   'sitting',
#   'on',
#   'on',
#   'on',
#   'on',
#   'a',
#   'sitting',
#   'on',
#   'a',
#   'on',
#   'sitting',
#   'sitting',
#   'on',
#   'on',
#   'sitting',
#   'on',
#   'sitting',
#   'a',
#   'a',
#   'in',
#   'a',
#   'on',
#   'on',
#   'on',
#   'a',
#   'a',
#   'a',
#   'on',
#   'sitting',
#   'a',
#   'on',
#   'on',
#   'on',
#   'sitting',
#   'sitting',
#   'on',
#   'sitting',
#   'on',
#   'in',
#   'on',
#   'a',
#   'sitting'],
#  ('of', 'scissors', 'on'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('scissors', 'on', 'a'): ['table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'table'],
#  ('on', 'a', 'table'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('a', 'table', 'a'): ['couple',
#   'bunch',
#   'train',
#   'close',
#   'person',
#   'man',
#   'window',
#   'sign',
#   'room',
#   'row',
#   'building',
#   'woman',
#   'person',
#   'pile',
#   'kitchen',
#   'bed',
#   'red',
#   'room',
#   'pair',
#   'building',
#   'window',
#   'red',
#   'collage',
#   'picture',
#   'view',
#   'close',
#   'snow',
#   'building',
#   'view',
#   'pair',
#   'black',
#   'close',
#   'white',
#   'close',
#   'red',
#   'bench',
#   'large',
#   'street',
#   'close',
#   'close',
#   'large',
#   'black',
#   'couple',
#   'close',
#   'window',
#   'large',
#   'close',
#   'woman',
#   'man',
#   'fire',
#   'man',
#   'train',
#   'man',
#   'close',
#   'snow',
#   'large',
#   'black',
#   'group',
#   'black',
#   'row',
#   'large',
#   'couple',
#   'picture',
#   'close',
#   'television',
#   'man',
#   'man',
#   'bunch',
#   'black',
#   'person',
#   'close',
#   'blue',
#   'close',
#   'group',
#   'close',
#   'close',
#   'close',
#   'black',
#   'close',
#   'close',
#   'close',
#   'living',
#   'desk',
#   'picture',
#   'close',
#   'group',
#   'bunch',
#   'room',
#   'pair',
#   'collage',
#   'bunch',
#   'bunch',
#   'close'],
#  ('table', 'a', 'couple'): ['of', 'of', 'of'],
#  ('a', 'couple', 'of'): ['animals',
#   'large',
#   'white',
#   'street',
#   'men',
#   'cakes',
#   'people',
#   'giraffes',
#   'men',
#   'cats',
#   'white'],
#  ('couple', 'of', 'animals'): ['that'],
#  ('of', 'animals', 'that'): ['are'],
#  ('animals', 'that', 'are'): ['in'],
#  ('that', 'are', 'in'): ['the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the'],
#  ('are', 'in', 'the'): ['water',
#   'air',
#   'woods',
#   'grass',
#   'grass',
#   'air',
#   'sky',
#   'sky'],
#  ('in', 'the', 'water'): ['a', 'a', 'a', 'a', 'a', 'a'],
#  ('the', 'water', 'a'): ['large',
#   'black',
#   'bedroom',
#   'stop',
#   'collage',
#   'bunch'],
#  ('water', 'a', 'large'): ['long'],
#  ('a', 'large', 'long'): ['train'],
#  ('large', 'long', 'train'): ['on'],
#  ('long', 'train', 'on'): ['a'],
#  ('train', 'on', 'a'): ['steel', 'track', 'track', 'track', 'track'],
#  ('on', 'a', 'steel'): ['track'],
#  ('a', 'steel', 'track'): ['a'],
#  ('steel', 'track', 'a'): ['man'],
#  ('track', 'a', 'man'): ['holding'],
#  ('a', 'man', 'holding'): ['a', 'a', 'a', 'a', 'a', 'a', 'an'],
#  ('man', 'holding', 'a'): ['cell',
#   'baseball',
#   'tennis',
#   'tennis',
#   'teddy',
#   'skateboard'],
#  ('cell', 'phone', 'up'): ['to'],
#  ('phone', 'up', 'to'): ['his'],
#  ('up', 'to', 'his'): ['ear'],
#  ('to', 'his', 'ear'): ['a'],
#  ('his', 'ear', 'a'): ['herd'],
#  ('ear', 'a', 'herd'): ['of'],
#  ('a', 'herd', 'of'): ['sheep', 'sheep'],
#  ('herd', 'of', 'sheep'): ['walking', 'grazing'],
#  ('of', 'sheep', 'walking'): ['across'],
#  ('sheep', 'walking', 'across'): ['a'],
#  ('walking', 'across', 'a'): ['snow', 'flooded'],
#  ('across', 'a', 'snow'): ['covered'],
#  ('a', 'snow', 'covered'): ['field',
#   'forest',
#   'ground',
#   'street',
#   'street',
#   'field',
#   'park',
#   'slope',
#   'mountain',
#   'ground'],
#  ('snow', 'covered', 'field'): ['a', 'with'],
#  ('covered', 'field', 'a'): ['view', 'close'],
#  ('field', 'a', 'view'): ['of'],
#  ('a', 'view', 'of'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'the',
#   'the'],
#  ('view', 'of', 'a'): ['building',
#   'mountain',
#   'window',
#   'window',
#   'room',
#   'city',
#   'city',
#   'train',
#   'mountain',
#   'building',
#   'window',
#   'clock',
#   'hallway',
#   'street',
#   'bridge',
#   'city',
#   'city',
#   'river',
#   'park',
#   'mountain',
#   'traffic',
#   'city',
#   'city',
#   'city',
#   'person'],
#  ('of', 'a', 'building'): ['with',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'with',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'holding',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('a', 'building', 'with'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('building', 'with', 'a'): ['clock',
#   'clock',
#   'clock',
#   'large',
#   'large',
#   'sky',
#   'clock',
#   'clock',
#   'sign',
#   'clock',
#   'sky',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'sky',
#   'sky',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'sky',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'clock'],
#  ('with', 'a', 'clock'): ['on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'tower',
#   'on',
#   'on',
#   'on',
#   'on',
#   'at',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'tower',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on'],
#  ('a', 'clock', 'on'): ['it',
#   'a',
#   'it',
#   'it',
#   'a',
#   'the',
#   'it',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'a',
#   'it',
#   'a',
#   'the',
#   'a',
#   'the',
#   'a',
#   'a',
#   'the',
#   'a',
#   'the',
#   'top',
#   'the',
#   'a',
#   'the',
#   'a',
#   'the',
#   'a',
#   'it',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'it',
#   'a',
#   'a',
#   'the',
#   'it',
#   'a',
#   'a',
#   'a',
#   'the',
#   'a',
#   'the',
#   'top',
#   'it',
#   'the',
#   'a',
#   'the',
#   'a',
#   'the',
#   'it',
#   'a',
#   'a',
#   'top',
#   'the',
#   'the',
#   'a',
#   'the',
#   'top',
#   'a',
#   'it',
#   'a',
#   'it',
#   'a',
#   'a',
#   'a',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'top',
#   'a',
#   'a',
#   'a',
#   'top',
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'a',
#   'a',
#   'it',
#   'a',
#   'the',
#   'the'],
#  ('clock', 'on', 'it'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'in',
#   'a'],
#  ('on', 'it', 'a'): ['close',
#   'close',
#   'view',
#   'close',
#   'group',
#   'living',
#   'close',
#   'sign',
#   'living',
#   'tennis',
#   'group',
#   'bicycle',
#   'wall',
#   'close',
#   'close',
#   'street',
#   'close',
#   'red',
#   'wall',
#   'black',
#   'close',
#   'group',
#   'group',
#   'blue',
#   'red',
#   'close',
#   'sign',
#   'pair',
#   'group',
#   'close',
#   'person',
#   'close',
#   'close',
#   'television',
#   'man',
#   'view',
#   'large',
#   'woman'],
#  ('it', 'a', 'close'): ['up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up'],
#  ('of', 'a', 'red'): ['stop',
#   'fire',
#   'and',
#   'and',
#   'fire',
#   'and',
#   'and',
#   'and',
#   'fire',
#   'and',
#   'and',
#   'and',
#   'and',
#   'suitcase'],
#  ('a', 'red', 'stop'): ['sign',
#   'sign',
#   'sign',
#   'sign',
#   'sign',
#   'sign',
#   'sign',
#   'sign',
#   'sign',
#   'sign',
#   'sign',
#   'sign',
#   'sign',
#   'sign'],
#  ('red', 'stop', 'sign'): ['a',
#   'sitting',
#   'sitting',
#   'sitting',
#   'sitting',
#   'sitting',
#   'sitting',
#   'sitting',
#   'with',
#   'sitting',
#   'sitting',
#   'sitting',
#   'sitting',
#   'sitting'],
#  ('stop', 'sign', 'a'): ['close', 'man', 'close'],
#  ('sign', 'a', 'close'): ['up', 'up'],
#  ('of', 'a', 'clock'): ['on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'tower',
#   'on',
#   'on',
#   'on',
#   'on',
#   'tower',
#   'on',
#   'on',
#   'on',
#   'tower',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on'],
#  ('clock', 'on', 'a'): ['wall',
#   'wall',
#   'wall',
#   'building',
#   'wall',
#   'wall',
#   'wall',
#   'wall',
#   'building',
#   'wall',
#   'building',
#   'wall',
#   'wall',
#   'wall',
#   'building',
#   'wall',
#   'building',
#   'wall',
#   'building',
#   'wall',
#   'wall',
#   'wall',
#   'building',
#   'wall',
#   'wall',
#   'building',
#   'pole',
#   'wall',
#   'wall',
#   'wall',
#   'building',
#   'wall',
#   'building',
#   'building',
#   'wall',
#   'wall',
#   'wall',
#   'wall',
#   'wall',
#   'wall',
#   'building',
#   'wall',
#   'wall',
#   'wall',
#   'building'],
#  ('on', 'a', 'wall'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'with',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'in',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('a', 'wall', 'a'): ['group',
#   'close',
#   'black',
#   'clock',
#   'book',
#   'pair',
#   'group',
#   'clock',
#   'stop',
#   'red',
#   'sign',
#   'bunch',
#   'room',
#   'building',
#   'close',
#   'close',
#   'blue',
#   'clock',
#   'man',
#   'plane',
#   'bunch',
#   'close',
#   'close',
#   'group',
#   'person',
#   'clock',
#   'sign',
#   'clock',
#   'close',
#   'group',
#   'white',
#   'close',
#   'red',
#   'bunch',
#   'bunch',
#   'bunch',
#   'close',
#   'parking',
#   'crowd',
#   'black',
#   'white',
#   'man',
#   'close',
#   'view',
#   'group',
#   'close'],
#  ('wall', 'a', 'group'): ['of', 'of', 'of', 'of', 'of'],
#  ('a', 'group', 'of'): ['people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'luggage',
#   'people',
#   'people',
#   'people',
#   'birds',
#   'people',
#   'people',
#   'people',
#   'boats',
#   'birds',
#   'birds',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'colorful',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'people',
#   'vases',
#   'people',
#   'people',
#   'people',
#   'people',
#   'umbrellas',
#   'people',
#   'people',
#   'birds',
#   'men',
#   'people',
#   'people',
#   'birds',
#   'people',
#   'people',
#   'people',
#   'people'],
#  ('group', 'of', 'people'): ['standing',
#   'standing',
#   'standing',
#   'standing',
#   'playing',
#   'standing',
#   'standing',
#   'standing',
#   'walking',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'walking',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'posing',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'standing',
#   'sitting',
#   'sitting',
#   'standing',
#   'sitting',
#   'walking',
#   'standing',
#   'standing',
#   'playing'],
#  ('of', 'people', 'standing'): ['around',
#   'in',
#   'around',
#   'in',
#   'next',
#   'next',
#   'in',
#   'in',
#   'on',
#   'in',
#   'next',
#   'in',
#   'in',
#   'outside',
#   'next',
#   'next',
#   'next',
#   'around',
#   'next',
#   'next',
#   'outside',
#   'next',
#   'on',
#   'on',
#   'on',
#   'next',
#   'next',
#   'next',
#   'on',
#   'around',
#   'in',
#   'around',
#   'in'],
#  ('people', 'standing', 'around'): ['a', 'a', 'a', 'a', 'a'],
#  ('standing', 'around', 'a'): ['giraffe',
#   'table',
#   'luggage',
#   'large',
#   'train'],
#  ('around', 'a', 'giraffe'): ['a'],
#  ('a', 'giraffe', 'a'): ['clock'],
#  ('giraffe', 'a', 'clock'): ['hanging'],
#  ('a', 'clock', 'hanging'): ['from', 'from', 'from', 'from', 'from'],
#  ('clock', 'hanging', 'from'): ['a', 'the', 'the', 'the', 'a', 'a', 'the'],
#  ('hanging', 'from', 'a'): ['ceiling',
#   'ceiling',
#   'ceiling',
#   'ceiling',
#   'pole',
#   'wall',
#   'wall',
#   'ceiling',
#   'ceiling',
#   'wall'],
#  ('from', 'a', 'ceiling'): ['in', 'in', 'a', 'a', 'in', 'a'],
#  ('a', 'ceiling', 'in'): ['a', 'a', 'a'],
#  ('ceiling', 'in', 'a'): ['room', 'room', 'room'],
#  ('in', 'a', 'room'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'holding',
#   'a',
#   'with',
#   'with',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('a', 'room', 'a'): ['black',
#   'bunch',
#   'pair',
#   'kitchen',
#   'large',
#   'close',
#   'close',
#   'close',
#   'close',
#   'group',
#   'bedroom',
#   'large',
#   'close',
#   'group',
#   'bunch',
#   'pair'],
#  ('room', 'a', 'black'): ['and'],
#  ('of', 'a', 'vase'): ['of',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'on',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'on',
#   'with'],
#  ('a', 'vase', 'of'): ['flowers'],
#  ('vase', 'of', 'flowers'): ['a'],
#  ('of', 'flowers', 'a'): ['kite', 'close'],
#  ('flowers', 'a', 'kite'): ['that'],
#  ('a', 'kite', 'that'): ['is'],
#  ('kite', 'that', 'is'): ['flying'],
#  ('that', 'is', 'flying'): ['in'],
#  ('is', 'flying', 'in'): ['the', 'the', 'the', 'the'],
#  ('flying', 'in', 'the'): ['sky',
#   'air',
#   'air',
#   'sky',
#   'sky',
#   'air',
#   'sky',
#   'sky',
#   'sky',
#   'air',
#   'sky',
#   'sky',
#   'sky'],
#  ('in', 'the', 'sky'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'over',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('the', 'sky', 'a'): ['row',
#   'stop',
#   'train',
#   'close',
#   'traffic',
#   'man',
#   'man',
#   'close',
#   'black',
#   'close',
#   'person'],
#  ('sky', 'a', 'row'): ['of'],
#  ('a', 'row', 'of'): ['white',
#   'wooden',
#   'urinals',
#   'urinals',
#   'colorful',
#   'white'],
#  ('row', 'of', 'white'): ['and', 'and'],
#  ('of', 'white', 'and'): ['red', 'blue'],
#  ('white', 'and', 'red'): ['vases', 'bus'],
#  ('and', 'red', 'vases'): ['on'],
#  ('red', 'vases', 'on'): ['display'],
#  ('vases', 'on', 'display'): ['a', 'a'],
#  ('on', 'display', 'a'): ['close', 'red'],
#  ('display', 'a', 'close'): ['up'],
#  ('of', 'a', 'toothbrush'): ['in'],
#  ('a', 'toothbrush', 'in'): ['a'],
#  ('toothbrush', 'in', 'a'): ['cup'],
#  ('in', 'a', 'cup'): ['a', 'a', 'a', 'a'],
#  ('a', 'cup', 'a'): ['large', 'pair', 'close', 'close'],
#  ('cup', 'a', 'large'): ['building'],
#  ('a', 'large', 'building'): ['with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'a',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'in',
#   'with',
#   'with'],
#  ('large', 'building', 'with'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('a', 'red', 'fire'): ['hydrant',
#   'hydrant',
#   'hydrant',
#   'hydrant',
#   'hydrant',
#   'hydrant',
#   'hydrant',
#   'hydrant',
#   'hydrant'],
#  ('red', 'fire', 'hydrant'): ['a',
#   'sitting',
#   'in',
#   'sitting',
#   'a',
#   'a',
#   'sitting',
#   'sitting',
#   'sitting'],
#  ('fire', 'hydrant', 'a'): ['black', 'close', 'pair', 'close', 'close', 'man'],
#  ('hydrant', 'a', 'black'): ['and'],
#  ('of', 'a', 'television'): ['screen'],
#  ('a', 'television', 'screen'): ['a', 'with', 'with'],
#  ('television', 'screen', 'a'): ['smart'],
#  ('screen', 'a', 'smart'): ['phone'],
#  ('a', 'smart', 'phone'): ['sitting'],
#  ('smart', 'phone', 'sitting'): ['on'],
#  ('phone', 'sitting', 'on'): ['top'],
#  ('sitting', 'on', 'top'): ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  ('on', 'top', 'of'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'it',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'it',
#   'a',
#   'it',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'it',
#   'a',
#   'it',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'it',
#   'it',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'it',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('top', 'of', 'a'): ['wooden',
#   'wooden',
#   'pole',
#   'table',
#   'table',
#   'wooden',
#   'table',
#   'wooden',
#   'wooden',
#   'conveyor',
#   'desk',
#   'wooden',
#   'table',
#   'wooden',
#   'desk',
#   'roof',
#   'wooden',
#   'table',
#   'pole',
#   'tennis',
#   'table',
#   'rock',
#   'wooden',
#   'table',
#   'table',
#   'field',
#   'sandy',
#   'table',
#   'table',
#   'wooden',
#   'wooden',
#   'tree',
#   'table',
#   'table',
#   'tennis',
#   'wooden',
#   'rock',
#   'table',
#   'table',
#   'wooden',
#   'table',
#   'table',
#   'table',
#   'fence',
#   'sandy',
#   'sandy',
#   'sandy',
#   'table',
#   'surfboard',
#   'table',
#   'table',
#   'beach',
#   'grass',
#   'surfboard',
#   'bridge',
#   'table',
#   'wooden',
#   'rail',
#   'beach',
#   'wooden',
#   'window',
#   'wooden',
#   'bench',
#   'table',
#   'table',
#   'wooden',
#   'table',
#   'table',
#   'roof',
#   'table',
#   'table',
#   'wooden'],
#  ('of', 'a', 'wooden'): ['table',
#   'table',
#   'table',
#   'table',
#   'table',
#   'desk',
#   'floor',
#   'floor',
#   'table',
#   'table',
#   'table',
#   'table',
#   'floor',
#   'bench',
#   'table',
#   'table',
#   'bench',
#   'table'],
#  ('a', 'wooden', 'table'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('wooden', 'table', 'a'): ['picture',
#   'close',
#   'hotel',
#   'stop',
#   'red',
#   'clock',
#   'blue',
#   'black',
#   'picture',
#   'white',
#   'close',
#   'group'],
#  ('table', 'a', 'picture'): ['of', 'of', 'of', 'of', 'of'],
#  ('a', 'picture', 'of'): ['a',
#   'herself',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'himself',
#   'a',
#   'a',
#   'herself',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'himself',
#   'a',
#   'herself',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('picture', 'of', 'a'): ['person',
#   'stop',
#   'clock',
#   'clock',
#   'person',
#   'cat',
#   'person',
#   'sign',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'clock',
#   'stop',
#   'stop',
#   'person',
#   'very',
#   'wall',
#   'stop',
#   'person',
#   'person',
#   'man',
#   'tennis',
#   'person',
#   'clock',
#   'plane',
#   'fence',
#   'dog',
#   'dog',
#   'man',
#   'cake'],
#  ('a', 'person', 'on'): ['a', 'a', 'a', 'a', 'a'],
#  ('person', 'on', 'a'): ['surfboard',
#   'surfboard',
#   'skateboard',
#   'surfboard',
#   'laptop'],
#  ('on', 'a', 'surfboard'): ['a', 'in', 'in', 'in'],
#  ('a', 'surfboard', 'a'): ['black', 'man', 'train', 'man', 'black', 'woman'],
#  ('surfboard', 'a', 'black'): ['and', 'and'],
#  ('of', 'a', 'man'): ['and',
#   'in',
#   'holding',
#   'in',
#   'holding',
#   'in',
#   'on',
#   'holding',
#   'walking',
#   'in',
#   'standing',
#   'in',
#   'wearing',
#   'wearing'],
#  ('a', 'man', 'and'): ['a', 'a', 'woman'],
#  ('man', 'and', 'a'): ['woman', 'woman'],
#  ('and', 'a', 'woman'): ['a', 'a'],
#  ('a', 'woman', 'a'): ['view', 'close', 'couple', 'group'],
#  ('woman', 'a', 'view'): ['of'],
#  ('of', 'a', 'mountain'): ['range', 'range', 'range'],
#  ('a', 'mountain', 'range'): ['from', 'from', 'from'],
#  ('mountain', 'range', 'from'): ['the', 'an', 'the'],
#  ('range', 'from', 'the'): ['ground', 'sun'],
#  ('from', 'the', 'ground'): ['a'],
#  ('the', 'ground', 'a'): ['person', 'view'],
#  ('ground', 'a', 'person'): ['on'],
#  ('a', 'surfboard', 'in'): ['the', 'the', 'front', 'the'],
#  ('surfboard', 'in', 'the'): ['water', 'water', 'water'],
#  ('water', 'a', 'black'): ['and'],
#  ('a', 'man', 'in'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('man', 'in', 'a'): ['suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit',
#   'suit'],
#  ('in', 'a', 'suit'): ['a',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'a',
#   'and',
#   'and',
#   'a'],
#  ('a', 'suit', 'a'): ['bunch', 'large', 'close'],
#  ('suit', 'a', 'bunch'): ['of'],
#  ('a', 'bunch', 'of'): ['snow',
#   'umbrellas',
#   'vases',
#   'different',
#   'different',
#   'surfboards',
#   'different',
#   'different',
#   'different',
#   'ties',
#   'birds',
#   'signs',
#   'different',
#   'trees',
#   'kites',
#   'umbrellas',
#   'colorful',
#   'surfboards',
#   'red',
#   'bananas',
#   'cupcakes',
#   'green',
#   'ties',
#   'scissors',
#   'different',
#   'different',
#   'umbrellas',
#   'vases',
#   'vases',
#   'stuffed',
#   'different',
#   'trees',
#   'green',
#   'green',
#   'kites',
#   'vases',
#   'kites',
#   'books',
#   'ties',
#   'different',
#   'kites'],
#  ('bunch', 'of', 'snow'): ['covered'],
#  ('of', 'snow', 'covered'): ['trees'],
#  ('snow', 'covered', 'trees'): ['in', 'a'],
#  ('covered', 'trees', 'in'): ['the'],
#  ('trees', 'in', 'the'): ['snow'],
#  ('in', 'the', 'snow'): ['a', 'a'],
#  ('the', 'snow', 'a'): ['woman', 'man', 'woman'],
#  ('snow', 'a', 'woman'): ['is', 'in'],
#  ('a', 'woman', 'is'): ['sitting', 'taking'],
#  ('woman', 'is', 'sitting'): ['on'],
#  ('is', 'sitting', 'on'): ['a'],
#  ('sitting', 'on', 'a'): ['bed',
#   'bench',
#   'bench',
#   'bench',
#   'sidewalk',
#   'tree',
#   'table',
#   'rock',
#   'bed',
#   'tree',
#   'bench',
#   'window',
#   'bench',
#   'bench',
#   'bench',
#   'bench',
#   'bed',
#   'surfboard',
#   'table',
#   'table',
#   'bench',
#   'shelf',
#   'bed'],
#  ('on', 'a', 'bed'): ['in', 'in', 'holding', 'in'],
#  ('a', 'bed', 'in'): ['a', 'a', 'a'],
#  ('bed', 'in', 'a'): ['room', 'room', 'room'],
#  ('room', 'a', 'bunch'): ['of', 'of', 'of'],
#  ('bunch', 'of', 'umbrellas'): ['that', 'on', 'that'],
#  ('of', 'umbrellas', 'that'): ['are', 'are'],
#  ('umbrellas', 'that', 'are'): ['in', 'in'],
#  ('in', 'the', 'air'): ['a', 'a', 'with', 'a', 'a', 'a', 'a', 'a'],
#  ('the', 'air', 'a'): ['black',
#   'group',
#   'teddy',
#   'close',
#   'red',
#   'close',
#   'group'],
#  ('air', 'a', 'black'): ['and'],
#  ('of', 'a', 'bedroom'): ['a'],
#  ('a', 'bedroom', 'a'): ['close'],
#  ('bedroom', 'a', 'close'): ['up'],
#  ('holding', 'a', 'frisbee'): ['a'],
#  ('a', 'frisbee', 'a'): ['red', 'sign'],
#  ('frisbee', 'a', 'red'): ['fire'],
#  ('fire', 'hydrant', 'sitting'): ['in', 'in', 'in', 'in', 'in', 'on', 'next'],
#  ('hydrant', 'sitting', 'in'): ['the', 'front', 'the', 'the', 'the'],
#  ('sitting', 'in', 'the'): ['middle',
#   'middle',
#   'water',
#   'middle',
#   'middle',
#   'snow'],
#  ('in', 'the', 'middle'): ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  ('the', 'middle', 'of'): ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'],
#  ('middle', 'of', 'a'): ['forest',
#   'city',
#   'forest',
#   'forest',
#   'lush',
#   'park',
#   'lush',
#   'street',
#   'field',
#   'forest'],
#  ('of', 'a', 'forest'): ['a', 'a', 'a', 'an'],
#  ('a', 'forest', 'a'): ['train',
#   'living',
#   'couple',
#   'close',
#   'close',
#   'couple'],
#  ('forest', 'a', 'train'): ['traveling'],
#  ('a', 'train', 'traveling'): ['through',
#   'through',
#   'through',
#   'through',
#   'through',
#   'down',
#   'through'],
#  ('train', 'traveling', 'through'): ['a', 'a', 'a', 'a', 'a', 'a'],
#  ('traveling', 'through', 'a'): ['lush',
#   'snow',
#   'lush',
#   'lush',
#   'lush',
#   'lush'],
#  ('through', 'a', 'lush'): ['green', 'green', 'green', 'green', 'green'],
#  ('a', 'lush', 'green'): ['forest',
#   'forest',
#   'forest',
#   'field',
#   'field',
#   'forest',
#   'field',
#   'forest'],
#  ('lush', 'green', 'forest'): ['a', 'a', 'a', 'a', 'a'],
#  ('green', 'forest', 'a'): ['black', 'black', 'view', 'yellow', 'close'],
#  ('forest', 'a', 'black'): ['and', 'and'],
#  ('of', 'a', 'window'): ['a',
#   'in',
#   'in',
#   'holding',
#   'a',
#   'a',
#   'in',
#   'with',
#   'with',
#   'a',
#   'a',
#   'with',
#   'sill'],
#  ('a', 'window', 'a'): ['close',
#   'view',
#   'large',
#   'room',
#   'black',
#   'close',
#   'person',
#   'close',
#   'large',
#   'large',
#   'close',
#   'woman',
#   'bedroom',
#   'room',
#   'man',
#   'clock',
#   'vase',
#   'kitchen',
#   'couple',
#   'clock'],
#  ('window', 'a', 'close'): ['up', 'up', 'up', 'up', 'up', 'up', 'up'],
#  ('holding', 'a', 'pair'): ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  ('of', 'scissors', 'a'): ['view',
#   'stop',
#   'close',
#   'picture',
#   'sign',
#   'man',
#   'building',
#   'snow',
#   'tree',
#   'close',
#   'living',
#   'group',
#   'clock',
#   'large',
#   'woman',
#   'bathroom',
#   'close',
#   'pair'],
#  ('scissors', 'a', 'view'): ['of'],
#  ('a', 'window', 'in'): ['a', 'a', 'a'],
#  ('window', 'in', 'a'): ['dark', 'dark', 'dark', 'room'],
#  ('in', 'a', 'dark'): ['room', 'room', 'room'],
#  ('a', 'dark', 'room'): ['a', 'a', 'a'],
#  ('dark', 'room', 'a'): ['person', 'close', 'view'],
#  ('room', 'a', 'person'): ['riding'],
#  ('a', 'person', 'riding'): ['a', 'a'],
#  ('person', 'riding', 'a'): ['surf', 'skate'],
#  ('riding', 'a', 'surf'): ['board'],
#  ('a', 'surf', 'board'): ['on', 'a', 'a', 'a'],
#  ('surf', 'board', 'on'): ['a'],
#  ('board', 'on', 'a'): ['wave', 'street'],
#  ('on', 'a', 'wave'): ['a'],
#  ('a', 'wave', 'a'): ['woman'],
#  ('wave', 'a', 'woman'): ['walking'],
#  ('a', 'woman', 'walking'): ['down', 'down'],
#  ('woman', 'walking', 'down'): ['a', 'a'],
#  ('walking', 'down', 'a'): ['street',
#   'street',
#   'street',
#   'street',
#   'street',
#   'street',
#   'street',
#   'street'],
#  ('down', 'a', 'street'): ['holding',
#   'a',
#   'a',
#   'next',
#   'a',
#   'a',
#   'a',
#   'holding',
#   'next',
#   'a',
#   'a'],
#  ('a', 'street', 'holding'): ['an', 'an'],
#  ('street', 'holding', 'an'): ['umbrella', 'umbrella'],
#  ('holding', 'an', 'umbrella'): ['a',
#   'a',
#   'a',
#   'a',
#   'in',
#   'a',
#   'over',
#   'a',
#   'while'],
#  ('an', 'umbrella', 'a'): ['black',
#   'black',
#   'sign',
#   'bathroom',
#   'red',
#   'man',
#   'close'],
#  ('umbrella', 'a', 'black'): ['and', 'and'],
#  ('of', 'a', 'bathroom'): ['mirror', 'sink', 'sink', 'sink', 'sink'],
#  ('a', 'bathroom', 'mirror'): ['a'],
#  ('bathroom', 'mirror', 'a'): ['black'],
#  ('mirror', 'a', 'black'): ['and', 'and'],
#  ('and', 'white', 'image'): ['of', 'of', 'of', 'of', 'of', 'of'],
#  ('white', 'image', 'of'): ['a', 'a', 'a', 'a', 'a', 'a'],
#  ('image', 'of', 'a'): ['vase', 'vase', 'vase', 'clock', 'clock', 'clock'],
#  ('a', 'vase', 'with'): ['flowers',
#   'a',
#   'flowers',
#   'flowers',
#   'flowers',
#   'flowers',
#   'flowers',
#   'flowers',
#   'flowers',
#   'flowers',
#   'flowers',
#   'flowers',
#   'flowers',
#   'flowers'],
#  ('vase', 'with', 'flowers'): ['in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in'],
#  ('with', 'flowers', 'in'): ['it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it'],
#  ('flowers', 'in', 'it'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'sitting',
#   'a',
#   'a',
#   'a'],
#  ('in', 'it', 'a'): ['view',
#   'close',
#   'large',
#   'white',
#   'woman',
#   'view',
#   'train',
#   'woman',
#   'man',
#   'close',
#   'pair',
#   'blue',
#   'window',
#   'close',
#   'woman',
#   'pair',
#   'park'],
#  ('it', 'a', 'view'): ['of', 'of', 'of', 'of'],
#  ('room', 'a', 'close'): ['up', 'up', 'up', 'up', 'up', 'up'],
#  ('phone', 'a', 'woman'): ['taking', 'in'],
#  ('a', 'woman', 'taking'): ['a', 'a'],
#  ('woman', 'taking', 'a'): ['picture', 'picture'],
#  ('taking', 'a', 'picture'): ['of', 'a', 'of', 'of', 'of', 'of'],
#  ('picture', 'of', 'herself'): ['in', 'in', 'in'],
#  ('of', 'herself', 'in'): ['a', 'the', 'a'],
#  ('herself', 'in', 'a'): ['mirror', 'mirror'],
#  ('in', 'a', 'mirror'): ['a', 'a', 'a', 'a', 'a'],
#  ('a', 'mirror', 'a'): ['black',
#   'bathroom',
#   'bathroom',
#   'woman',
#   'bathroom',
#   'laptop',
#   'woman',
#   'room',
#   'pair',
#   'train',
#   'man',
#   'bathroom',
#   'woman',
#   'group',
#   'close'],
#  ('vase', 'with', 'a'): ['flower'],
#  ('with', 'a', 'flower'): ['in'],
#  ('a', 'flower', 'in'): ['it'],
#  ('flower', 'in', 'it'): ['a'],
#  ('person', 'holding', 'an'): ['umbrella',
#   'open',
#   'umbrella',
#   'apple',
#   'apple',
#   'umbrella',
#   'apple',
#   'umbrella',
#   'open'],
#  ('a', 'person', 'taking'): ['a'],
#  ('person', 'taking', 'a'): ['picture'],
#  ('a', 'picture', 'a'): ['close', 'woman', 'man'],
#  ('picture', 'a', 'close'): ['up'],
#  ('of', 'a', 'black'): ['and', 'and', 'and', 'and', 'and', 'and', 'and'],
#  ('and', 'white', 'clock'): ['a', 'a', 'on', 'a', 'a', 'a', 'is', 'a', 'a'],
#  ('white', 'clock', 'a'): ['group',
#   'picture',
#   'close',
#   'small',
#   'woman',
#   'close',
#   'view'],
#  ('clock', 'a', 'group'): ['of'],
#  ('people', 'standing', 'in'): ['front',
#   'front',
#   'a',
#   'front',
#   'front',
#   'front',
#   'front',
#   'a',
#   'front'],
#  ('standing', 'in', 'front'): ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  ('in', 'front', 'of'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'her',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('front', 'of', 'a'): ['tall',
#   'building',
#   'building',
#   'display',
#   'building',
#   'building',
#   'building',
#   'building',
#   'building',
#   'mirror',
#   'train',
#   'table',
#   'window',
#   'window',
#   'large',
#   'window',
#   'building',
#   'mirror',
#   'tv',
#   'mirror',
#   'building',
#   'christmas',
#   'building',
#   'store',
#   'sign',
#   'mirror',
#   'building',
#   'building',
#   'building',
#   'building',
#   'building',
#   'laptop',
#   'window',
#   'mirror',
#   'mirror',
#   'window',
#   'toilet',
#   'mirror',
#   'mirror',
#   'large',
#   'brick',
#   'store',
#   'building'],
#  ('of', 'a', 'tall'): ['building'],
#  ('a', 'tall', 'building'): ['a', 'a'],
#  ('tall', 'building', 'a'): ['close', 'clock'],
#  ('building', 'a', 'close'): ['up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up'],
#  ('of', 'a', 'book'): ['on'],
#  ('a', 'book', 'on'): ['a'],
#  ('book', 'on', 'a'): ['table'],
#  ('table', 'a', 'bunch'): ['of', 'of', 'of', 'of', 'of'],
#  ('bunch', 'of', 'vases'): ['that', 'that', 'that', 'that'],
#  ('of', 'vases', 'that'): ['have', 'are', 'are', 'are'],
#  ('vases', 'that', 'have'): ['flowers'],
#  ('that', 'have', 'flowers'): ['in'],
#  ('have', 'flowers', 'in'): ['them'],
#  ('flowers', 'in', 'them'): ['a'],
#  ('in', 'them', 'a'): ['view'],
#  ('them', 'a', 'view'): ['of'],
#  ('of', 'a', 'room'): ['with'],
#  ('a', 'room', 'with'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('room', 'with', 'a'): ['bed',
#   'bed',
#   'bed',
#   'bed',
#   'bed',
#   'table',
#   'bed',
#   'couch',
#   'couch',
#   'bed',
#   'bed',
#   'bed',
#   'bed',
#   'bed',
#   'bed',
#   'bed',
#   'window',
#   'fire',
#   'suitcase',
#   'window',
#   'bed'],
#  ('with', 'a', 'bed'): ['and',
#   'and',
#   'and',
#   ',',
#   'and',
#   ',',
#   ',',
#   'desk',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   ',',
#   'and',
#   ','],
#  ('a', 'bed', 'and'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('bed', 'and', 'a'): ['window',
#   'large',
#   'chair',
#   'table',
#   'chair',
#   'window',
#   'large',
#   'large',
#   'desk',
#   'window',
#   'large',
#   'table',
#   'window',
#   'large'],
#  ('and', 'a', 'window'): ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'],
#  ('window', 'a', 'view'): ['of', 'of'],
#  ('of', 'a', 'city'): ['street',
#   'street',
#   'a',
#   'street',
#   'street',
#   'street',
#   'street',
#   'street'],
#  ('a', 'city', 'street'): ['with',
#   'at',
#   'at',
#   'at',
#   'filled',
#   'at',
#   'at',
#   'at',
#   'at'],
#  ('city', 'street', 'with'): ['a'],
#  ('street', 'with', 'a'): ['lot'],
#  ('with', 'a', 'lot'): ['of', 'of'],
#  ('a', 'lot', 'of'): ['snow', 'luggage'],
#  ('lot', 'of', 'snow'): ['a'],
#  ('of', 'snow', 'a'): ['close'],
#  ('snow', 'a', 'close'): ['up'],
#  ('of', 'a', 'street'): ['sign',
#   'sign',
#   'sign',
#   'sign',
#   'light',
#   'sign',
#   'sign',
#   'sign',
#   'sign',
#   'sign',
#   'a',
#   'sign'],
#  ('a', 'street', 'sign'): ['with',
#   'with',
#   'attached',
#   'with',
#   'with',
#   'that',
#   'with',
#   'with',
#   'with',
#   'above',
#   'above',
#   'with',
#   'with',
#   'with',
#   'with',
#   'a',
#   'a'],
#  ('street', 'sign', 'with'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('sign', 'with', 'a'): ['sky',
#   'building',
#   'street',
#   'sticker',
#   'sky',
#   'sky',
#   'sky',
#   'sky',
#   'sky',
#   'sky',
#   'sky',
#   'street',
#   'sky',
#   'street',
#   'building',
#   'sticker',
#   'clock',
#   'sky',
#   'sky',
#   'sky',
#   'sky'],
#  ('with', 'a', 'sky'): ['background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background',
#   'background'],
#  ('a', 'sky', 'background'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('sky', 'background', 'a'): ['large',
#   'picture',
#   'man',
#   'bed',
#   'pair',
#   'black',
#   'red',
#   'close',
#   'wall',
#   'stop',
#   'room',
#   'collage',
#   'clock',
#   'pair',
#   'traffic',
#   'clock',
#   'picture',
#   'bunch',
#   'black',
#   'close',
#   'colorful',
#   'bedroom',
#   'blue'],
#  ('background', 'a', 'large'): ['building'],
#  ('city', 'street', 'at'): ['night',
#   'night',
#   'night',
#   'night',
#   'night',
#   'night',
#   'night'],
#  ('street', 'at', 'night'): ['a', 'a', 'a', 'a', 'a', 'a', 'with'],
#  ('at', 'night', 'a'): ['group', 'sign', 'close', 'close', 'view', 'man'],
#  ('night', 'a', 'group'): ['of'],
#  ('around', 'a', 'table'): ['a', 'a'],
#  ('table', 'a', 'train'): ['traveling', 'on'],
#  ('through', 'a', 'snow'): ['covered'],
#  ('snow', 'covered', 'forest'): ['a'],
#  ('covered', 'forest', 'a'): ['close'],
#  ('forest', 'a', 'close'): ['up', 'up', 'up', 'up'],
#  ('a', 'red', 'and'): ['white',
#   'white',
#   'yellow',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'yellow',
#   'white',
#   'white',
#   'white'],
#  ('red', 'and', 'white'): ['toothbrush',
#   'clock',
#   'kite',
#   'polka',
#   'vase',
#   'polka',
#   'frisbee',
#   'kite',
#   'fire',
#   'comforter',
#   'clock',
#   'umbrella',
#   'cake',
#   'umbrella',
#   'clock',
#   'clock',
#   'clock',
#   'fire'],
#  ('and', 'white', 'toothbrush'): ['a'],
#  ('white', 'toothbrush', 'a'): ['bunch'],
#  ('toothbrush', 'a', 'bunch'): ['of'],
#  ('bunch', 'of', 'different'): ['colored',
#   'colored',
#   'types',
#   'colored',
#   'colored',
#   'colored',
#   'colored',
#   'colored',
#   'types',
#   'colored'],
#  ('of', 'different', 'colored'): ['ties',
#   'ties',
#   'vases',
#   'ties',
#   'vases',
#   'furniture',
#   'flowers',
#   'ties',
#   'toothbrushes',
#   'ties'],
#  ('different', 'colored', 'ties'): ['on',
#   'on',
#   'hanging',
#   'hanging',
#   'hanging'],
#  ('colored', 'ties', 'on'): ['a', 'a'],
#  ('ties', 'on', 'a'): ['table', 'table'],
#  ('table', 'a', 'close'): ['up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up',
#   'up'],
#  ('a', 'person', 'wearing'): ['a', 'a', 'a', 'a', 'a', 'a'],
#  ('person', 'wearing', 'a'): ['tie', 'tie', 'suit', 'suit', 'tie', 'suit'],
#  ('wearing', 'a', 'tie'): ['a', 'a', 'a', 'a', 'a'],
#  ('a', 'tie', 'a'): ['large', 'train', 'woman', 'black', 'close', 'group'],
#  ('tie', 'a', 'large'): ['clock'],
#  ('a', 'large', 'clock'): ['mounted',
#   'tower',
#   'tower',
#   'mounted',
#   'mounted',
#   'tower',
#   'hanging',
#   'tower',
#   'on',
#   'tower',
#   'tower',
#   'with',
#   'hanging'],
#  ('large', 'clock', 'mounted'): ['to', 'to', 'to'],
#  ('clock', 'mounted', 'to'): ['the', 'the', 'the', 'the'],
# ...
#  ('of', 'food', 'and'): ['drinks'],
#  ('food', 'and', 'drinks'): ['a'],
#  ('and', 'drinks', 'a'): ['red'],
#  ('drinks', 'a', 'red'): ['umbrella'],
#  ('a', 'red', 'umbrella'): ['sitting', 'hanging', 'a'],
#  ('red', 'umbrella', 'sitting'): ['on'],
#  ('table', 'a', 'red'): ['fire', 'stop', 'stop', 'and'],
#  ('fire', 'hydrant', 'in'): ['front'],
#  ('hydrant', 'in', 'front'): ['of'],
#  ('group', 'of', 'luggage'): ['sitting'],
#  ('of', 'luggage', 'sitting'): ['on', 'on', 'on'],
#  ('luggage', 'sitting', 'on'): ['top', 'top', 'top'],
#  ('of', 'a', 'conveyor'): ['belt'],
#  ('a', 'conveyor', 'belt'): ['a'],
#  ('conveyor', 'belt', 'a'): ['group'],
#  ('belt', 'a', 'group'): ['of'],
#  ('of', 'people', 'walking'): ['down', 'down', 'down'],
#  ('people', 'walking', 'down'): ['a', 'a', 'a'],
#  ('a', 'street', 'a'): ['group',
#   'close',
#   'close',
#   'close',
#   'woman',
#   'close',
#   'view',
#   'city',
#   'man'],
#  ('street', 'a', 'group'): ['of'],
#  ('of', 'a', 'desk'): ['a', 'a'],
#  ('a', 'desk', 'a'): ['red', 'kitchen', 'close', 'group'],
#  ('desk', 'a', 'red'): ['stop'],
#  ('of', 'a', 'road'): ['a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a'],
#  ('a', 'road', 'a'): ['dog',
#   'clock',
#   'traffic',
#   'close',
#   'close',
#   'statue',
#   'close',
#   'close',
#   'traffic',
#   'close',
#   'black',
#   'man',
#   'picture',
#   'couple'],
#  ('road', 'a', 'dog'): ['sitting'],
#  ('a', 'dog', 'sitting'): ['in'],
#  ('dog', 'sitting', 'in'): ['a'],
#  ('sitting', 'in', 'a'): ['chair', 'bedroom', 'chair', 'bathroom', 'bedroom'],
#  ('in', 'a', 'chair'): ['in', 'holding'],
#  ('a', 'chair', 'in'): ['a', 'it'],
#  ('chair', 'in', 'a'): ['room'],
#  ('room', 'a', 'large'): ['building', 'building'],
#  ('place', 'a', 'building'): ['with'],
#  ('with', 'a', 'sign'): ['on'],
#  ('side', 'of', 'it'): ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'],
#  ('of', 'it', 'a'): ['room',
#   'close',
#   'close',
#   'bunch',
#   'close',
#   'sign',
#   'clock',
#   'bunch',
#   'bunch',
#   'close',
#   'picture',
#   'close',
#   'man',
#   'man',
#   'bathroom',
#   'large',
#   'flock',
#   'city'],
#  ('it', 'a', 'room'): ['with'],
#  ('a', 'bed', ','): ['table', 'a', 'a', 'dresser', 'a'],
#  ('bed', ',', 'table'): ['and'],
#  (',', 'table', 'and'): ['chairs'],
#  ('table', 'and', 'chairs'): ['a'],
#  ('and', 'chairs', 'a'): ['blue'],
#  ('chairs', 'a', 'blue'): ['and'],
#  ('a', 'blue', 'and'): ['white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white',
#   'white'],
#  ('blue', 'and', 'white'): ['clock',
#   'suitcase',
#   'sign',
#   'polka',
#   'bus',
#   'striped',
#   'sign',
#   'bird',
#   'umbrella',
#   'vase',
#   'cake',
#   'clock',
#   'cake',
#   'polka',
#   'decorated',
#   'plane',
#   'umbrella',
#   'kite',
#   'striped'],
#  ('white', 'clock', 'on'): ['a'],
#  ('a', 'wall', 'with'): ['graffiti', 'a', 'a', 'a'],
#  ('wall', 'with', 'graffiti'): ['on'],
#  ('with', 'graffiti', 'on'): ['it'],
#  ('graffiti', 'on', 'it'): ['a'],
#  ('it', 'a', 'tennis'): ['racket'],
#  ('a', 'tennis', 'racket'): ['and', 'a', 'on', 'in', 'a'],
#  ('tennis', 'racket', 'and'): ['a'],
#  ('racket', 'and', 'a'): ['ball'],
#  ('and', 'a', 'ball'): ['on'],
#  ('a', 'ball', 'on'): ['a'],
#  ('ball', 'on', 'a'): ['tennis'],
#  ('on', 'a', 'tennis'): ['court', 'court', 'court'],
#  ('a', 'tennis', 'court'): ['a', 'a', 'holding', 'a', 'a'],
#  ('tennis', 'court', 'a'): ['man', 'close', 'close', 'woman'],
#  ('court', 'a', 'man'): ['standing'],
#  ('of', 'a', 'mirror'): ['holding',
#   'on',
#   'with',
#   'a',
#   'holding',
#   'a',
#   'holding',
#   'holding',
#   'holding',
#   'a',
#   'on',
#   'with'],
#  ('a', 'mirror', 'holding'): ['a', 'a', 'a', 'a', 'a'],
#  ('mirror', 'holding', 'a'): ['camera', 'toothbrush', 'cell', 'cell', 'cell'],
#  ('holding', 'a', 'camera'): ['a'],
#  ('a', 'camera', 'a'): ['train'],
#  ('camera', 'a', 'train'): ['station'],
#  ('a', 'train', 'station'): ['with', 'a', 'with', 'a', 'with', 'with', 'a'],
#  ('train', 'station', 'with'): ['a', 'a', 'a', 'a'],
#  ('station', 'with', 'a'): ['train', 'train', 'train', 'train'],
#  ('with', 'a', 'train'): ['passing', 'on', 'on', 'on', 'passing', 'passing'],
#  ('a', 'train', 'passing'): ['by', 'by', 'by'],
#  ('train', 'passing', 'by'): ['a', 'a', 'a'],
#  ('passing', 'by', 'a'): ['tree', 'picture', 'group'],
#  ('by', 'a', 'tree'): ['in'],
#  ('a', 'tree', 'in'): ['the', 'the', 'the', 'a'],
#  ('tree', 'in', 'the'): ['middle', 'middle', 'middle'],
#  ('forest', 'a', 'living'): ['room'],
#  ('a', 'sink', ','): ['mirror', 'refrigerator', 'stove'],
#  ('sink', ',', 'mirror'): ['and'],
#  (',', 'mirror', 'and'): ['shower'],
#  ('mirror', 'and', 'shower'): ['a'],
#  ('and', 'shower', 'a'): ['wooden'],
#  ('shower', 'a', 'wooden'): ['bench'],
#  ('a', 'wooden', 'bench'): ['sitting', 'sitting', 'a', 'sitting', 'a'],
#  ('wooden', 'bench', 'sitting'): ['next', 'in', 'next'],
#  ('bench', 'sitting', 'next'): ['to', 'to'],
#  ('next', 'to', 'a'): ['window',
#   'window',
#   'tall',
#   'window',
#   'forest',
#   'fire',
#   'forest',
#   'window',
#   'surfboard',
#   'woman',
#   'woman',
#   'wall',
#   'bridge',
#   'window',
#   'clock',
#   'tree',
#   'pile',
#   'pile',
#   'window',
#   'fire',
#   'clock',
#   'building',
#   'forest',
#   'brick'],
#  ('to', 'a', 'window'): ['a', 'a', 'a', 'a', 'a', 'a'],
#  ('window', 'a', 'large'): ['clock', 'red', 'building'],
#  ('wall', 'a', 'stop'): ['sign'],
#  ('stop', 'sign', 'on'): ['the', 'the', 'the'],
#  ('table', 'a', 'building'): ['with', 'that', 'with'],
#  ('the', 'top', 'of'): ['it', 'it'],
#  ('top', 'of', 'it'): ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'],
#  ('wall', 'a', 'red'): ['stop', 'and'],
#  ('building', 'a', 'stack'): ['of'],
#  ('a', 'stack', 'of'): ['books'],
#  ('stack', 'of', 'books'): ['sitting'],
#  ('of', 'books', 'sitting'): ['on'],
#  ('books', 'sitting', 'on'): ['top'],
#  ('a', 'wooden', 'desk'): ['a'],
#  ('wooden', 'desk', 'a'): ['room'],
#  ('desk', 'a', 'room'): ['with'],
#  ('and', 'a', 'table'): ['in', 'a', 'a', 'a', 'a'],
#  ('a', 'table', 'in'): ['it'],
#  ('table', 'in', 'it'): ['a'],
#  ('it', 'a', 'woman'): ['standing', 'standing', 'in', 'sitting'],
#  ('a', 'woman', 'standing'): ['in',
#   'in',
#   'in',
#   'in',
#   'on',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in'],
#  ('woman', 'standing', 'in'): ['front',
#   'front',
#   'front',
#   'front',
#   'front',
#   'front',
#   'front',
#   'front',
#   'a',
#   'front',
#   'front',
#   'a',
#   'a'],
#  ('of', 'a', 'train'): ['station', 'from'],
#  ('train', 'station', 'a'): ['woman', 'group', 'group'],
#  ('station', 'a', 'woman'): ['standing'],
#  ('lot', 'of', 'luggage'): ['a'],
#  ('of', 'luggage', 'a'): ['bed', 'woman', 'blue'],
#  ('luggage', 'a', 'bed'): ['sitting'],
#  ('a', 'bed', 'sitting'): ['in', 'in'],
#  ('bed', 'sitting', 'in'): ['a', 'a'],
#  ('in', 'a', 'bedroom'): ['next', 'next'],
#  ('a', 'bedroom', 'next'): ['to', 'to'],
#  ('bedroom', 'next', 'to'): ['a', 'a'],
#  ('window', 'a', 'room'): ['with', 'with'],
#  ('with', 'a', 'table'): [','],
#  ('a', 'table', ','): ['chairs'],
#  ('table', ',', 'chairs'): ['and'],
#  (',', 'chairs', 'and'): ['a'],
#  ('chairs', 'and', 'a'): ['table'],
#  ('table', 'a', 'woman'): ['standing', 'holding'],
#  ('a', 'window', 'holding'): ['an'],
#  ('window', 'holding', 'an'): ['umbrella'],
#  ('umbrella', 'a', 'bathroom'): ['with'],
#  ('mirror', 'a', 'woman'): ['in', 'in', 'standing', 'standing', 'holding'],
#  ('a', 'woman', 'in'): ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'],
#  ('woman', 'in', 'a'): ['black',
#   'white',
#   'red',
#   'bikini',
#   'pink',
#   'pink',
#   'pink',
#   'suit',
#   'short',
#   'red',
#   'red'],
#  ('in', 'a', 'black'): ['dress'],
#  ('a', 'black', 'dress'): ['and'],
#  ('black', 'dress', 'and'): ['a'],
#  ('dress', 'and', 'a'): ['white', 'red', 'red', 'pink'],
#  ('and', 'a', 'white'): ['shirt'],
#  ('a', 'white', 'shirt'): ['a', 'and'],
#  ('white', 'shirt', 'a'): ['stop'],
#  ('shirt', 'a', 'stop'): ['sign'],
#  ('road', 'a', 'clock'): ['hanging'],
#  ('hanging', 'from', 'the'): ['side',
#   'ceiling',
#   'ceiling',
#   'ceiling',
#   'ceiling'],
#  ('from', 'the', 'side'): ['of'],
#  ('a', 'man', 'riding'): ['a', 'a', 'a', 'a', 'a', 'a', 'a'],
#  ('man', 'riding', 'a'): ['skateboard',
#   'skateboard',
#   'skateboard',
#   'snowboard',
#   'wave',
#   'wave',
#   'skateboard'],
#  ('riding', 'a', 'skateboard'): ['up', 'up', 'up', 'down'],
#  ('a', 'skateboard', 'up'): ['the', 'the', 'the'],
#  ('skateboard', 'up', 'the'): ['side', 'side', 'side'],
#  ('up', 'the', 'side'): ['of', 'of', 'of'],
#  ('of', 'a', 'ramp'): ['a', 'a', 'a'],
#  ('a', 'ramp', 'a'): ['clock', 'large', 'red'],
#  ('ramp', 'a', 'clock'): ['on'],
#  ('road', 'a', 'traffic'): ['light', 'light'],
#  ('a', 'traffic', 'light'): ['sitting',
#   'a',
#   'sitting',
#   'with',
#   'with',
#   'sitting',
#   'sitting',
#   'with',
#   'sitting',
#   'with',
#   'sitting',
#   'on',
#   'and'],
#  ('traffic', 'light', 'sitting'): ['next', 'on', 'on', 'on', 'on', 'on'],
#  ('light', 'sitting', 'next'): ['to'],
#  ('to', 'a', 'tall'): ['building'],
#  ('from', 'the', 'ceiling'): ['of', 'of', 'of', 'of'],
#  ('the', 'ceiling', 'of'): ['a', 'a', 'a', 'a'],
#  ('ceiling', 'of', 'a'): ['building', 'building', 'building', 'building'],
#  ('background', 'a', 'bed'): ['with'],
#  ('a', 'bed', 'with'): ['a', 'a', 'a', 'a', 'a'],
#  ('bed', 'with', 'a'): ['blue', 'wooden', 'red', 'wooden', 'black'],
#  ('with', 'a', 'blue'): ['blanket', 'background', 'umbrella', 'background'],
#  ('a', 'blue', 'blanket'): ['and', 'a'],
#  ('blue', 'blanket', 'and'): ['a'],
#  ('blanket', 'and', 'a'): ['blue'],
#  ('and', 'a', 'blue'): ['blanket'],
#  ('blue', 'blanket', 'a'): ['black'],
#  ('blanket', 'a', 'black'): ['and'],
#  ('building', 'a', 'collage'): ['of'],
#  ('holding', 'an', 'open'): ['umbrella', 'umbrella'],
#  ('an', 'open', 'umbrella'): ['a', 'a', 'a'],
#  ('open', 'umbrella', 'a'): ['close', 'picture', 'close'],
#  ('umbrella', 'a', 'close'): ['up', 'up', 'up', 'up', 'up'],
#  ('holding', 'a', 'surf'): ['board', 'board', 'board'],
#  ('surf', 'board', 'a'): ['white', 'group', 'large'],
#  ('board', 'a', 'white'): ['toilet'],
#  ('a', 'white', 'toilet'): ['with', 'sitting'],
#  ('white', 'toilet', 'with'): ['a'],
#  ('toilet', 'with', 'a'): ['black'],
#  ('with', 'a', 'black'): ['and', 'and'],
#  ('and', 'white', 'background'): ['a', 'a', 'a', 'a'],
#  ('white', 'background', 'a'): ['stop', 'close', 'close', 'close'],
#  ('sign', 'that', 'has'): ['been', 'a'],
#  ('that', 'has', 'been'): ['vandalized'],
#  ('has', 'been', 'vandalized'): ['with'],
#  ('been', 'vandalized', 'with'): ['graffiti'],
#  ('vandalized', 'with', 'graffiti'): ['a'],
#  ('with', 'graffiti', 'a'): ['close'],
#  ('graffiti', 'a', 'close'): ['up'],
#  ('wall', 'a', 'sign'): ['that', 'with'],
#  ('scissors', 'a', 'man'): ['wearing'],
#  ('a', 'man', 'wearing'): ['a', 'a', 'a', 'a'],
#  ('man', 'wearing', 'a'): ['blue', 'hat', 'tie', 'tie'],
#  ('wearing', 'a', 'blue'): ['shirt'],
#  ('a', 'blue', 'shirt'): ['and'],
#  ('blue', 'shirt', 'and'): ['a'],
#  ('shirt', 'and', 'a'): ['red'],
#  ('and', 'a', 'red'): ['tie', 'tie', 'hat'],
#  ('a', 'red', 'tie'): ['a', 'a'],
#  ('red', 'tie', 'a'): ['black', 'woman'],
#  ('tie', 'a', 'black'): ['and', 'and'],
#  ('of', 'a', 'plane'): ['flying', 'on'],
#  ('a', 'plane', 'flying'): ['in', 'in', 'over'],
#  ('plane', 'flying', 'in'): ['the', 'the', 'the'],
#  ('air', 'a', 'group'): ['of', 'of'],
#  ('people', 'standing', 'on'): ['a', 'top', 'top', 'top', 'top'],
#  ('standing', 'on', 'a'): ['beach',
#   'skateboard',
#   'sidewalk',
#   'tennis',
#   'sidewalk',
#   'rock',
#   'sidewalk'],
#  ('on', 'a', 'beach'): ['flying', 'near', 'a', 'flying'],
#  ('a', 'beach', 'flying'): ['kites', 'a'],
#  ('beach', 'flying', 'kites'): ['a'],
#  ('flying', 'kites', 'a'): ['building'],
#  ('kites', 'a', 'building'): ['with'],
#  ('tie', 'a', 'train'): ['traveling'],
#  ('of', 'a', 'snowy'): ['mountain'],
#  ('a', 'snowy', 'mountain'): ['a'],
#  ('snowy', 'mountain', 'a'): ['black'],
#  ('mountain', 'a', 'black'): ['and'],
#  ('large', 'white', 'bed'): ['sitting'],
#  ('white', 'bed', 'sitting'): ['next', 'next'],
#  ('bed', 'sitting', 'next'): ['to', 'to'],
#  ('scissors', 'a', 'building'): ['with'],
#  ('it', 'a', 'bunch'): ['of', 'of', 'of'],
#  ('different', 'colored', 'vases'): ['on', 'sitting'],
#  ('colored', 'vases', 'on'): ['display'],
#  ('display', 'a', 'red'): ['and'],
#  ('red', 'and', 'yellow'): ['fire', 'train', 'umbrellas', 'fire'],
#  ('and', 'yellow', 'fire'): ['hydrant', 'hydrant'],
#  ('yellow', 'fire', 'hydrant'): ['sitting', 'a'],
#  ('sitting', 'in', 'front'): ['of', 'of', 'of'],
#  ('umbrella', 'a', 'red'): ['fire', 'and'],
#  ('forest', 'a', 'couple'): ['of', 'of'],
#  ('couple', 'of', 'large'): ['vases'],
#  ('of', 'large', 'vases'): ['sitting'],
#  ('large', 'vases', 'sitting'): ['next'],
#  ('vases', 'sitting', 'next'): ['to'],
#  ('other', 'a', 'large'): ['window'],
#  ('large', 'window', 'with'): ['a'],
#  ('clock', 'on', 'top'): ['of', 'of', 'of', 'of', 'of', 'of'],
#  ('holding', 'a', 'box'): ['with'],
#  ('a', 'box', 'with'): ['a'],
#  ('box', 'with', 'a'): ['doughnut'],
#  ('with', 'a', 'doughnut'): ['in'],
#  ('a', 'doughnut', 'in'): ['it'],
#  ('doughnut', 'in', 'it'): ['a'],
#  ('a', 'train', 'from'): ['the'],
#  ('train', 'from', 'the'): ['window'],
#  ('from', 'the', 'window'): ['a', 'a'],
#  ('the', 'window', 'a'): ['view', 'bathroom'],
#  ('range', 'from', 'an'): ['airplane'],
#  ('from', 'an', 'airplane'): ['window'],
#  ('an', 'airplane', 'window'): ['a'],
#  ('airplane', 'window', 'a'): ['close'],
#  ('holding', 'an', 'apple'): ['a', 'a', 'in'],
#  ('an', 'apple', 'a'): ['man', 'close'],
#  ('apple', 'a', 'man'): ['riding'],
#  ('ramp', 'a', 'large'): ['body'],
#  ('a', 'large', 'body'): ['of', 'of', 'of'],
#  ('large', 'body', 'of'): ['water', 'water', 'water'],
#  ('body', 'of', 'water'): ['with', 'a', 'a', 'a', 'a', 'a', 'next', 'a'],
#  ('of', 'water', 'with'): ['a'],
#  ('water', 'with', 'a'): ['sky'],
#  ('background', 'a', 'pair'): ['of', 'of'],
#  ('table', 'a', 'pile'): ['of'],
#  ('a', 'pile', 'of'): ['luggage', 'luggage', 'luggage', 'luggage'],
#  ('pile', 'of', 'luggage'): ['sitting', 'sitting', 'a', 'a'],
#  ('a', 'wooden', 'floor'): ['a', 'a', 'a'],
#  ('wooden', 'floor', 'a'): ['room', 'bunch', 'picture'],
#  ('floor', 'a', 'room'): ['with'],
#  ('bed', ',', 'a'): ['chair', 'chair', 'table'],
#  (',', 'a', 'chair'): ['and', 'and'],
#  ('a', 'chair', 'and'): ['a', 'a'],
#  ('chair', 'and', 'a'): ['lamp', 'window'],
#  ('and', 'a', 'lamp'): ['a'],
#  ('a', 'lamp', 'a'): ['living'],
#  ('lamp', 'a', 'living'): ['room'],
#  ('living', 'room', 'with'): ['a', 'a', 'a'],
#  ('with', 'a', 'couch'): ['and', 'and'],
#  ('a', 'couch', 'and'): ['a', 'a'],
#  ('couch', 'and', 'a'): ['table', 'table'],
#  ('table', 'a', 'kitchen'): ['with'],
#  ('sink', ',', 'refrigerator'): [','],
#  (',', 'refrigerator', ','): ['stove'],
#  ('refrigerator', ',', 'stove'): [','],
#  (',', 'stove', ','): ['and', 'and'],
#  ('stove', ',', 'and'): ['cabinets', 'refrigerator'],
#  (',', 'and', 'cabinets'): ['a'],
#  ('and', 'cabinets', 'a'): ['living'],
#  ('cabinets', 'a', 'living'): ['room'],
#  ('table', 'a', 'bed'): ['with'],
#  ('with', 'a', 'wooden'): ['frame', 'frame'],
#  ('a', 'wooden', 'frame'): ['and', 'a', 'and'],
#  ('wooden', 'frame', 'and'): ['a', 'a'],
#  ('frame', 'and', 'a'): ['wooden', 'wooden'],
#  ('and', 'a', 'wooden'): ['frame', 'headboard'],
#  ('wooden', 'frame', 'a'): ['white'],
#  ('frame', 'a', 'white'): ['refrigerator'],
#  ('a', 'white', 'refrigerator'): ['freezer'],
#  ('white', 'refrigerator', 'freezer'): ['sitting'],
#  ('refrigerator', 'freezer', 'sitting'): ['inside'],
#  ('freezer', 'sitting', 'inside'): ['of'],
#  ('sitting', 'inside', 'of'): ['a'],
#  ('inside', 'of', 'a'): ['kitchen'],
#  ('of', 'a', 'kitchen'): ['a'],
#  ('a', 'kitchen', 'a'): ['bathroom', 'white'],
#  ('kitchen', 'a', 'bathroom'): ['with'],
#  ('and', 'a', 'shower'): ['a'],
#  ('a', 'shower', 'a'): ['bathroom'],
#  ('shower', 'a', 'bathroom'): ['with'],
#  ('a', 'shower', ','): ['sink'],
#  ('shower', ',', 'sink'): ['and'],
#  (',', 'sink', 'and'): ['mirror', 'mirror'],
#  ('sink', 'and', 'mirror'): ['a', 'a'],
#  ('mirror', 'a', 'laptop'): ['computer'],
#  ('desk', 'a', 'kitchen'): ['with'],
#  ('stove', 'and', 'oven'): ['in'],
#  ('and', 'oven', 'in'): ['it'],
#  ('oven', 'in', 'it'): ['a'],
#  ('it', 'a', 'train'): ['station'],
#  ('a', 'train', 'on'): ['the', 'it', 'it', 'a', 'a', 'a'],
#  ...}

# %% [markdown]
# We can now use the Markov model to make *predictions*. Given the information in the Markov model of `textInspiration.txt`, what words are likely to follow the sequence of words `white photo of`? We can find out simply by getting the value for the key for that sequence:

# %%
textInspiration_markov_model[('white', 'photo', 'of')]
# Out:
# ['a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'an',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a']

# %% [markdown]
# This tells us that the sequence `white photo of` is followed by `a` 90% of the time, `an,` 10% of the time.

# %% [markdown]
# ### Markov chains: Generating text from a Markov model
#
# The Markov models we created above don't just give us interesting statistical probabilities. It also allows us generate a *new* text with those probabilities by *chaining together predictions*. Here’s how we’ll do it, starting with the order 2 character-level Markov model of `condescendences`: (1) start with the initial n-gram (`co`)—those are the first two characters of our output. (2) Now, look at the last *n* characters of output, where *n* is the order of the n-grams in our table, and find those characters in the “n-grams” column. (3) Choose randomly among the possibilities in the corresponding “next” column, and append that letter to the output. (Sometimes, as with `co`, there’s only one possibility). (4) If you chose “end of text,” then the algorithm is over. Otherwise, repeat the process starting with (2).

# %% [markdown]
# Why `range(100)`? No reason, really—I just picked 100 as a reasonable number for the maximum number of times the Markov chain should produce attempt to append to the output. Because there's a loop in this particular model (`nd` -> `e`, `de` -> `n`, `en` -> `d`), any time you generate text from this Markov chain, it could potentially go on infinitely. Limiting the number to `100` makes sure that it doesn't ever actually do that. You should adjust the number based on what you need the Markov chain to do.
#
# ### A function to generate from a Markov model
#
# The `gen_from_model()` function below is a more general version of the code that we just wrote that works with lists and strings and n-grams of any length:

# %%
import random
def gen_from_model(n, model, start=None, max_gen=100):
    if start is None:
        start = random.choice(list(model.keys()))
    output = list(start)
    for i in range(max_gen):
        start = tuple(output[-n:])
        next_item = random.choice(model[start])
        if next_item is None:
            break
        else:
            output.append(next_item)
    return output

# %% [markdown]
# The `gen_from_model()` function's first parameter is the length of n-gram; the second parameter is a Markov model, as returned from `markov_model()` defined above, and the third parameter is the "seed" n-gram to start the generation from. The `gen_from_model()` function always returns a list.

# %% [markdown]
# So if you're working with a character-level Markov chain, you'll want to glue the list back together into a string:

# %% [markdown]
# If you leave out the "seed," this function will just pick a random n-gram to start with:

# %% [markdown]
# ### Advanced Markov style: Generating lines
#
# You can use the `gen_from_model()` function to generate word-level Markov chains as well:

# %%
genesis_word_model = markov_model(3, open("textInspiration.txt").read().split())

# %%
generated_words = gen_from_model(3, genesis_word_model, ('photo', 'of', 'a' ))
print(' '.join(generated_words))
# Out:
# photo of a pair of scissors on a table a building with a clock on a wall a white and black microwave a black and white photo of a person flying a kite a person riding a skate board on a street a view of a traffic light a traffic light sitting on the side of it a picture of a person holding a tennis racket on a court a large building with a clock on it a tennis racket on a court a large building with a clock on the top a bunch of green and yellow flowers in a tree a

# %% [markdown]
# This looks good! But there's a problem: the generation of the text just sorta... keeps going. Actually it goes on for exactly 100 words, which is also the maximum number of iterations specified in the function. We can make it go even longer by supplying a fourth parameter to the function:

# %%
generated_words = gen_from_model(3, genesis_word_model, ('photo', 'of', 'a'), 500)
print(' '.join(generated_words))
# Out:
# photo of a red and white toothbrush a bunch of umbrellas that are in the air a close up of a nintendo wii controller a red and white fire hydrant a close up of a tennis racket a person holding a pair of scissors a close up of a black and white background a close up of a person holding an open umbrella a close up of a person holding a pair of scissors a group of people standing around a luggage carousel a picture of a wall with a wall mounted to the side of a building a group of people standing next to each other a large window with a building in the background a black and white photo of a man in a suit and tie walking down a street a woman in a black dress and a white shirt and black shorts holding a tennis racket a close up of a pair of scissors on a table a bunch of trees that are in the sky a close up of a person holding an umbrella a black and white photo of a window with a picture of a dog on it a group of people sitting on top of a pole a picture of a fence in a house a group of people standing in front of a window sill a statue of a bear in the middle of a lush green field a train traveling through a lush green forest a black and white image of a vase with flowers in it a woman standing in front of a table a couple of people standing in a room with a bed desk chair and television a building with a clock on a wall a clock on a building a close up of a cake on a table a sign that is on the side of a wall with a clock tower in the dark a traffic light with a street light a birthday cake with a red light on it a pair of scissors in her hands a man in a suit and tie a close up of a person wearing a suit and tie a close up of a street sign above it a close up of a clock on a building a picture of a man and a woman a couple of white sinks in a room a close up of a pair of scissors a group of people standing in a room with a bed and a large mirror above a sink a living room filled with furniture and a fire place a collage of photos showing a man and woman sitting on a bench with a book a woman in a black dress and a white shirt and black shorts holding a tennis racquet on top of a rock a large building with a large building with a clock on the side of a ramp a clock on it a sign that says on the side of a building a sign that says on

# %% [markdown]
# The reason for this is that unless the Markov chain generator reaches the "end of text" token, it'll just keep going on forever. And the longer the text, the less likely it is that the "end of text" token will be reached.
#
# Maybe this is okay, but the underlying text actually has some structure in it: each line of the file is actually a verse. If you want to generate individual *verses*, you need to treat each line separately, producing an end-of-text token for each line. The following function does just this by creating a model, adding each item from a list to the model as a separate item, and returning the combined model:

# %%
def markov_model_from_sequences(n, sequences):
    model = {}
    for item in sequences:
        add_to_model(model, n, item)
    return model

# %% [markdown]
# This function expects to receive a list of sequences (the sequences can be either lists or strings, depending on if you want a word-level model or a character-level model). So, for example:

# %%
textInspiration_lines = open("textInspiration.txt").readlines() # all of the lines from the file
# textInspiration_lines_words will be a list of lists of words in each line
textInspiration_lines_words = [line.strip().split() for line in textInspiration_lines] # strip whitespace and split into words
textInspiration_lines_model = markov_model_from_sequences(2, textInspiration_lines_words)

# %% [markdown]
# The `textInspiration_lines_model` variable now contains a Markov model with end-of-text tokens where they should be, at the end of each line. Generating from this model, we get:

# %%
for i in range(10):
    print("verse", i, "-", ' '.join(gen_from_model(2, textInspiration_lines_model)))
# Out:
# verse 0 - meter on the side of a snow covered mountain with a clock on the wall of a person "s" reflection in a suit
# verse 1 - and chairs
# verse 2 - , table and chairs
# verse 3 - of boats that are sitting on the side of a nintendo wii controller
# verse 4 - it sitting on the wall
# verse 5 - oven in it
# verse 6 - clock mounted to the side of a window
# verse 7 - brushing his teeth in the sky
# verse 8 - and white kite flying in the air
# verse 9 - sitting under a tree

# %% [markdown]
# Better—the verses are ending at appropriate places—but still not quite right, since we're generating from random keys in the Markov model! To make this absolutely correct, we'd want to *start* each line with an n-gram that also occurred at the start of each line in the original text file. To do this, we'll work in two passes. First, get the list of lists of words:

# %%
textInspiration_lines = open("textInspiration.txt").readlines() # all of the lines from the file
# textInspiration_lines_words will be a list of lists of words in each line
textInspiration_lines_words = [line.strip().split() for line in textInspiration_lines] # strip whitespace and split into words

# %% [markdown]
# Now, get the n-grams at the start of each line:

# %%
textInspiration_starts = [item[:2] for item in textInspiration_lines_words if len(item) >= 2]

# %% [markdown]
# Now create the Markov model:

# %%
textInspiration_lines_model = markov_model_from_sequences(2, textInspiration_lines_words)

# %% [markdown]
# And generate from it, picking a random "start" for each line:

# %%
for i in range(10):
    start = random.choice(textInspiration_starts)
    generated = gen_from_model(2, textInspiration_lines_model, random.choice(textInspiration_starts))
    print("verse", i, "-", ' '.join(generated))
# Out:
# verse 0 - a picture of a black and white image of a table
# verse 1 - a red and white photo of a red stop sign
# verse 2 - a bed with a building
# verse 3 - a close up of a person wearing a tie
# verse 4 - a young boy riding a skateboard up the side of a blue umbrella sitting on top of a roof
# verse 5 - a group of people standing next to each other
# verse 6 - a close up of a person holding a pair of scissors on a table
# verse 7 - a woman is taking a picture of a building
# verse 8 - a close up of a road
# verse 9 - a close up of a person holding an apple

# %% [markdown]
# ### Putting it together
#
# The `markov_generate_from_sequences()` function below wraps up everything above into one function that takes an n-gram length, a list of sequences (e.g., a list of lists of words for a word-level Markov model, or a list of strings for a character-level Markov model), and a number of lines to generate, and returns that many generated lines, starting the generation only with n-grams that begin lines in the source file:

# %%
def markov_generate_from_sequences(n, sequences, count, max_gen=100):
    starts = [item[:n] for item in sequences if len(item) >= n]
    model = markov_model_from_sequences(n, sequences)
    return [gen_from_model(n, model, random.choice(starts), max_gen)
           for i in range(count)]

# %% [markdown]
# Here's how to use this function to generate from a character-level Markov model of `textInspiration.txt`:

# %%
textInspiration_lines = [line.strip() for line in open("textInspiration.txt").readlines()]
for item in markov_generate_from_sequences(6, textInspiration_lines, 20):
    print(''.join(item))
# Out:
# a bench sitting on a bedroom with scissors sitting on top of a city street sign that says
# a large crowd of people standing next to a window in a mirror
# a close up of a pair of scissors on a wall
# a picture of a train on a wall
# a close up of people standing in front of a man standing in front of a road
# a close up of a mirror
# a bathroom with a clock on it
# a close up of a person holding holding with a clock on the wall
# a bathroom sink
# a close up of a toothbrush
# a close up of people standing in a suit and tie holding with flowers in it
# a picture of a stop sign that is flying in the middle of men standing on a beach
# a picture of a window
# a row of urinals mounted to it
# a close up of a table
# a close up of a clock on it
# a couple of white and white photo of a clock
# a pair of scissors on a sidewalk holding around a lamp
# a bunch of vases on a table
# a blue and cabinets

# %% [markdown]
# And from a word-level Markov model of `textInspiration.txt`:

# %%
textInspiration_words = [line.strip().split() for line in open("textInspiration.txt").readlines()]
for item in markov_generate_from_sequences(5, textInspiration_words, 14):
    print(' '.join(item))
# Out:
# a red stop sign sitting on the side of a building
# a bed sitting in a bedroom next to a window
# a man is holding a bunch of bananas
# a street light with a street light hanging from it
# a close up of a person holding a kite
# a white refrigerator freezer sitting inside of a kitchen
# a red umbrella sitting on top of a rock
# a person cutting a piece of paper with scissors
# a group of boats that are sitting in the water
# a large building with a clock on it
# a bunch of surfboards are lined up on a rack
# a room with a bed and a large window
# a flock of birds flying over a large body of water next to a bridge
# a close up of a stuffed animal on a table

# %% [markdown]
# A fun thing to do is combine *two* source texts and make a Markov model from the combination. So for example, read in the lines of both `textInspiration.txt` and `textoriginal-caption.txt` and put them into the same list:

# %%
frost_lines = [line.strip() for line in open("textInspiration.txt").readlines()]
genesis_lines = [line.strip() for line in open("textoriginal-caption.txt").readlines()]
both_lines = frost_lines + genesis_lines
for item in markov_generate_from_sequences(5, both_lines, 14, max_gen=150):
    print(''.join(item))
# Out:
# a couple of a blue and a field
# a pair of scissors
# a close up of a kitchen with a bench
# a clock on a chair
# a red suitcases on a table
# a table
# a man standing with snowy mountain in a room
# a building on a wall
# a pair of scissors sitting next to each other
# a black and a fire hydrant sitting on top of a building
# a close up of a street filled with a stop sign on a wall
# a man walking down a surfboard
# a bowl of a person holding
# a group of a table

# %% [markdown]
# The resulting text has properties of both of the underlying source texts!

# %% [markdown]
# ### Putting it all *even more together*
#
# If you're really super lazy, the `markov_generate_from_lines_in_file()` function below does allll the work for you. It takes an n-gram length, an open filehandle to read from, the number of lines to generate, and the string `char` for a character-level Markov model and `word` for a word-level model. It returns the requested number of lines generated from a Markov model of the desired order and level.

# %%
def markov_generate_from_lines_in_file(n, filehandle, count, level='word', max_gen=100):
    if level == 'word':
        glue = ''
        sequences = [item.strip() for item in filehandle.readlines()]
    elif level == 'char':
        glue = ' '
        sequences = [item.strip().split() for item in filehandle.readlines()]
    generated = markov_generate_from_sequences(n, sequences, count, max_gen)
    return [glue.join(item) for item in generated]

# %% [markdown]
# So, for example, to generate twenty lines from an order-3 model of `textInspiration.txt`:

# %%
for item in markov_generate_from_lines_in_file(7, open("textInspiration.txt"), 20, 'char'):
    print(item)
# Out:
# a statue of a bear in the middle of a forest
# a sign that says on the side of a building
# a building that has a bunch of signs on it
# a close up of a pair of scissors on a table
# a close up of a clock on a wall
# a man in a suit and tie
# a bench on a beach near a body of water
# a large window in a room with a window
# a window that has a clock on it
# a woman standing in front of a window holding an umbrella
# a blue and white bus driving down a street
# a close up of a vandalized street sign
# a room filled with lots of wooden furniture
# a close up of a pair of scissors on a table
# a pair of scissors sitting on top of a table
# a clock on a building with a sky background
# a bed sitting in a bedroom next to a window
# a red stop sign sitting on the side of a road
# a close up of a traffic light on a pole
# a red and white umbrella with a blue background

# %% [markdown]
# Or an order-3 word-level model of `textInspiration.txt`:

# %%
for item in markov_generate_from_lines_in_file(6, open("textInspiration.txt"), 5, 'word'):
    print(item)
    print("")
# Out:
# a stop sign with a street signs on it
#
# a pair of scissors sitting next to a bridge
#
# a close up of people standing next to a window
#
# a black and white photo of a wooden floor
#
# a group of a person holding a cell phone

# %%
for item in markov_generate_from_lines_in_file(12, open("textInspiration.txt"), 15, 'word'):
    print(item)
    print("")
# Out:
# a small boat in a body of water
#
# a plane flying in the air
#
# a clock mounted to the side of a ramp
#
# a red stop sign
#
# a close up of a person holding a nintendo wii controller
#
# a woman walking down a street
#
# a pair of skis sitting on top of a table
#
# a room with a window
#
# a close up of a pair of scissors
#
# a group of people standing next to a surfboard
#
# a picture of a person holding a tennis racket on a court
#
# a clock hanging from the ceiling of a building
#
# a woman holding a pair of scissors sitting on top of a wooden table
#
# a red and white fire hydrant
#
# a man riding a wave on top of a table
